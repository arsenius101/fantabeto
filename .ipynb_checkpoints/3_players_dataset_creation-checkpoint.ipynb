# %% [markdown]
# Players dataset creation
#
# The Fantacalcio players list is manually downloaded from https://www.fantacalcio.it/quotazioni-fantacalcio
#
# Here, the players database is generated, by merging the Fantacalcio list to stats downloaded from http://fbref.com

# %%
import pandas as pd

# %% [markdown]
# Load fbref data for outfield players and goalkeepers.
#
# Generate fbref player list, adding player surname (with special characters replaced to normal ones)

# %%
rcsv = pd.read_csv('fbref_data/outfield_players.csv')   
outfield_players = pd.DataFrame(rcsv)

rcsv = pd.read_csv('fbref_data/keepers_players.csv')   
keeper_players = pd.DataFrame(rcsv)

# %%
players = pd.concat(   [ outfield_players[['player', 'team']], keeper_players[['player', 'team']] ], axis = 0, ignore_index = True)

keepers_ID = len(outfield_players)

players
# Out:
#                  player        team
# 0     Oliver Abildgaard        Como
# 1         Tammy Abraham        Roma
# 2      Francesco Acerbi       Inter
# 3             Che Adams      Torino
# 4      Michel Aebischer     Bologna
# ..                  ...         ...
# 325         Yann Sommer       Inter
# 326         Zion Suzuki       Parma
# 327         Mile Svilar        Roma
# 328  Pietro Terracciano  Fiorentina
# 329       Devis Vásquez      Empoli
#
# [330 rows x 2 columns]

# %%
import unicodedata

def normalize_name(input_str):
    nfkd_form = unicodedata.normalize('NFKD', input_str)
    only_ascii = nfkd_form.encode('ASCII', 'ignore')
    return only_ascii.decode('utf-8')

# %%
players['surname'] = players['player']
players['initial'] = players['player']

for i in range(players.shape[0]):
    players['surname'][i] = players['surname'][i].split(' ')[-1]
    players['surname'][i] = normalize_name(players['surname'][i]).replace('\'', '')
    
    
    players['initial'][i] = players['player'][i][0]

# %%
print(players[['player', 'surname']].to_string())
# Out:
#                          player           surname
# 0             Oliver Abildgaard        Abildgaard
# 1                 Tammy Abraham           Abraham
# 2              Francesco Acerbi            Acerbi
# 3                     Che Adams             Adams
# 4              Michel Aebischer         Aebischer
# 5               Pontus Almqvist          Almqvist
# 6                Giorgio Altare            Altare
# 7                Sofyan Amrabat           Amrabat
# 8                      Angeliño          Angelino
# 9              Kristjan Asllani           Asllani
# 10              Tommaso Augello           Augello
# 11               Carlos Augusto           Augusto
# 12           Yann Aurel Bisseck           Bisseck
# 13                   Paulo Azzi              Azzi
# 14                 Milan Badelj            Badelj
# 15               Mitchel Bakker            Bakker
# 16             Tommaso Baldanzi          Baldanzi
# 17                Botond Balogh            Balogh
# 18                 Lameck Banda             Banda
# 19                  Mattia Bani              Bani
# 20               Federico Barba             Barba
# 21               Nicolò Barella           Barella
# 22         Federico Baschirotto       Baschirotto
# 23              Daniele Baselli           Baselli
# 24           Alessandro Bastoni           Bastoni
# 25               Reda Belahyane         Belahyane
# 26              Raoul Bellanova         Bellanova
# 27               Andrea Belotti           Belotti
# 28              Ismaël Bennacer          Bennacer
# 29                Medon Berisha           Berisha
# 30               Adrian Bernabe           Bernabe
# 31                  Sam Beukema           Beukema
# 32            Alessandro Bianco            Bianco
# 33                   Jaka Bijol             Bijol
# 34            Cristiano Biraghi           Biraghi
# 35           Samuele Birindelli        Birindelli
# 36                 Warren Bondo             Bondo
# 37              Ange-Yoan Bonny             Bonny
# 38           Matthias Braunöder         Braunoder
# 39               Gleison Bremer            Bremer
# 40                      Brenner           Brenner
# 41            Marco Brescianini       Brescianini
# 42              Liberato Cacace            Cacace
# 43              Davide Calabria          Calabria
# 44               Luca Caldirola         Caldirola
# 45             Hakan Çalhanoğlu        Calhanoglu
# 46                Drissa Camara            Camara
# 47             Nicolò Cambiaghi         Cambiaghi
# 48              Andrea Cambiaso          Cambiaso
# 49           Matteo Cancellieri       Cancellieri
# 50             Gianluca Caprari           Caprari
# 51             Francesco Caputo            Caputo
# 52                Nicolò Casale            Casale
# 53               Federico Cassa             Cassa
# 54         Valentín Castellanos       Castellanos
# 55              Santiago Castro            Castro
# 56          Gaetano Castrovilli       Castrovilli
# 57                   Zeki Çelik             Celik
# 58                Alberto Cerri             Cerri
# 59               Walid Cheddira          Cheddira
# 60             Samuel Chukwueze         Chukwueze
# 61           Alessandro Circati           Circati
# 62                    Saúl Coco              Coco
# 63              Lorenzo Colombo           Colombo
# 64               Andrea Colpani           Colpani
# 65               Pietro Comuzzo           Comuzzo
# 66                Diego Coppola           Coppola
# 67            Lassana Coulibaly         Coulibaly
# 68               Woyo Coulibaly         Coulibaly
# 69              Bryan Cristante         Cristante
# 70                Domen Črnigoj           Crnigoj
# 71              Patrick Cutrone           Cutrone
# 72                Wylan Cyprien           Cyprien
# 73               Lucas Da Cunha             Cunha
# 74               Thijs Dallinga          Dallinga
# 75               Matteo Darmian           Darmian
# 76             Juan David Cabal             Cabal
# 77                 Keinan Davis             Davis
# 78             Paweł Dawidowicz        Dawidowicz
# 79         Charles De Ketelaere         Ketelaere
# 80               Koni De Winter            Winter
# 81            Alessandro Deiola            Deiola
# 82          Fisayo Dele-Bashiru      Dele-Bashiru
# 83                  Ali Dembélé           Dembele
# 84          Michele Di Gregorio          Gregorio
# 85          Giovanni Di Lorenzo           Lorenzo
# 86             Federico Dimarco           Dimarco
# 87               Berat Djimsiti          Djimsiti
# 88                         Dodô              Dodo
# 89                Patrick Dorgu             Dorgu
# 90                 Artem Dovbyk            Dovbyk
# 91                  Ondrej Duda              Duda
# 92              Denzel Dumfries          Dumfries
# 93                Alfred Duncan            Duncan
# 94                 Paulo Dybala            Dybala
# 95                      Éderson           Ederson
# 96            Kingsley Ehizibue          Ehizibue
# 97                 Jeff Ekhator           Ekhator
# 98           Jurgen Ekkelenkamp       Ekkelenkamp
# 99               Emmanuel Ekong             Ekong
# 100           Mikael Ellertsson        Ellertsson
# 101           Yannik Engelhardt        Engelhardt
# 102                Martin Erlic             Erlic
# 103         Sebastiano Esposito          Esposito
# 104              Nahuel Estévez           Estevez
# 105            Giovanni Fabbian           Fabbian
# 106              Nicolò Fagioli           Fagioli
# 107           Wladimiro Falcone           Falcone
# 108              Jacopo Fazzini           Fazzini
# 109             Davide Frattesi          Frattesi
# 110             Morten Frendrup          Frendrup
# 111                Martin Frese             Frese
# 112                Remo Freuler           Freuler
# 113      Alessandro Gabrielloni       Gabrielloni
# 114         Roberto Gagliardini       Gagliardini
# 272                 Mile Svilar            Svilar
# 273             Michael Svoboda           Svoboda
# 274               Adrien Tameze            Tameze
# 275                Mehdi Taremi            Taremi
# 276               Loum Tchaouna          Tchaouna
# 277          Jackson Tchatchoua        Tchatchoua
# 278            Casper Tengstedt         Tengstedt
# 279          Pietro Terracciano       Terracciano
# 280             Florian Thauvin           Thauvin
# 281                Malick Thiaw             Thiaw
# 282              Morten Thorsby           Thorsby
# 283             Khéphren Thuram            Thuram
# 284               Marcus Thuram            Thuram
# 285               Fikayo Tomori            Tomori
# 286             Emanuele Valeri            Valeri
# 287               Devis Vásquez           Vasquez
# 288               Johan Vásquez           Vasquez
# 289               Matías Vecino            Vecino
# 290                Simone Verdi             Verdi
# 291             Samuele Vignato           Vignato
# 292                 Mattia Viti              Viti
# 293                     Vitinha           Vitinha
# 294              Dušan Vlahović          Vlahovic
# 295        Alessandro Vogliacco         Vogliacco
# 296              Mërgim Vojvoda           Vojvoda
# 297       Sebastian Walukiewicz       Walukiewicz
# 298                Timothy Weah              Weah
# 299            Mateusz Wieteska          Wieteska
# 300                Kenan Yıldız              Yldz
# 301             Mattia Zaccagni          Zaccagni
# 302             Nicola Zalewski          Zalewski
# 303  Andre-Frank Zambo Anguissa          Anguissa
# 304           Francesco Zampano           Zampano
# 305           Alessandro Zanoli            Zanoli
# 306                Duván Zapata            Zapata
# 307              Gabriele Zappa             Zappa
# 308           Davide Zappacosta        Zappacosta
# 309               Jordan Zemura            Zemura
# 310         Michele Di Gregorio          Gregorio
# 311           Wladimiro Falcone           Falcone
# 312           Pierluigi Gollini           Gollini
# 313               Jesse Joronen           Joronen
# 314                Mike Maignan           Maignan
# 315                  Alex Meret             Meret
# 316      Vanja Milinković-Savić  Milinkovic-Savic
# 317             Lorenzo Montipò           Montipo
# 318                  Juan Musso             Musso
# 319                Maduka Okoye             Okoye
# 320          Semuel Pizzignacco       Pizzignacco
# 321               Ivan Provedel          Provedel
# 322                  Pepe Reina             Reina
# 323              Simone Scuffet           Scuffet
# 324            Łukasz Skorupski         Skorupski
# 325                 Yann Sommer            Sommer
# 326                 Zion Suzuki            Suzuki
# 327                 Mile Svilar            Svilar
# 328          Pietro Terracciano       Terracciano
# 329               Devis Vásquez           Vasquez

# %% [markdown]
# Replace the surname for some specific players, according to config/name_fix.txt file.
#
# This is done for players for which the decoded fbref surname doesn't correspond to Fantacalcio list.

# %%
rcsv = pd.read_csv('config/name_fix.txt')   
name_fix = pd.DataFrame(rcsv)

for i in range(name_fix.shape[0]):
    for j in range(players.shape[0]):
        if(players['surname'][j].lower() == name_fix['FROM'][i].lower() and players['team'][j].lower() == name_fix['TEAM'][i].lower()):
            players['surname'][j] = name_fix['TO'][i]
            print(name_fix['TO'][i])

name_fix
# Out:
#           FROM           TO           TEAM
# 0      stigard     Ostigard         Napoli
# 1      Min-jae          Kim         Napoli
# 2       Hjlund      Hojlund       Atalanta
# 3       Gytkjr     Gytkjaer          Monza
# 4       Carlos      Augusto          Inter
# 5         Mhle       Maehle       Atalanta
# 6          Kjr        Kjaer          Milan
# 7       uricic     Djuricic      Sampdoria
# 8         uric       Djuric  Hellas Verona
# 9       Arthur       Cabral     Fiorentina
# 10    Martinez      Alvarez       Sassuolo
# 11  Gumundsson  Gudmundsson          Genoa
# 12  Kristensen       Nissen           Roma

# %% [markdown]
# Load players from Fantacalcio list.

# %%
fc_data = pd.read_excel('fantacalcio/Quotazioni_Fantacalcio.xlsx', 'Tutti', header = 1)

fc_players = fc_data [['Id', 'R', 'Nome', 'Squadra']]

fc_players = fc_players.rename(columns = {'Id' : 'id', 'R': 'r', 'Nome' : 'name', 'Squadra' : 'team'})

fc_players['surname'] = fc_players['name']
fc_players['initial'] = fc_players['name']


for i in range(fc_players.shape[0]):
    spl = normalize_name( fc_players['name'][i].replace('\'', '') ).split(' ')
    if('.' in spl[-1]):
        fc_players.loc[i, 'surname'] = spl[-2]
        fc_players.loc[i, 'initial'] = spl[-1][0]
    else:
        fc_players.loc[i, 'surname'] = spl[-1]
        fc_players.loc[i, 'initial'] = ''
    
fc_players
# Out:
#        id  r         name      team      surname initial
# 0    2428  P       Sommer     Inter       Sommer
# 1    5876  P  Di Gregorio  Juventus     Gregorio
# 2    4312  P      Maignan     Milan      Maignan
# 3     572  P        Meret    Napoli        Meret
# 4    5841  P       Svilar      Roma       Svilar
# ..    ... ..          ...       ...          ...     ...
# 511  6598  A     Mutandwa  Cagliari     Mutandwa
# 512  6603  A   Joao Costa      Roma        Costa
# 513  6648  A        Jasim      Como        Jasim
# 514  6670  A  Charpentier     Parma  Charpentier
# 515  6822  A      Ekhator     Genoa      Ekhator
#
# [516 rows x 6 columns]

# %% [markdown]
# Associate players from Fantacalcio list to ID for FBref data.

# %%
fc_players['fb_ID'] = fc_players['id']

for i in range(fc_players.shape[0]):
    fc_players.loc[i, 'fb_ID']  = -1
    
    for j in range(players.shape[0]):
        if(fc_players['team'][i].lower() in players['team'][j].lower()):
            if(fc_players['surname'][i].lower() == players['surname'][j].lower()):              
                # if(fc_players['initial'][i] == '' or fc_players['initial'][i].lower() == players['initial'][j].lower()):
                if((fc_players['r'][i] == 'P') == (j >= keepers_ID)): # check wether they're a goalkeeper for both FBREF and Fantacalcio
                    fc_players.loc[i, 'fb_ID'] = j

# %% [markdown]
# Print players for which the association failed.
#
# Most of them are players who didn't play a single Serie A game this season with their team. If that is the case, and there is data from their previous team, that is taken here.
#
# Others are ones for which the FBRef surname doesn't correspond to Fantacalcio one.
#
#
# For example, Cabral is Arthur for FBref.
#
# Correction is made in the name_fix code above.

# %%
exceptions = ['pellegrini', 'bastoni', 'kristensen'] # exceptions for such players that have the same surname as others (Berardi A., Luca Pellegrini)

for i in range(fc_players.shape[0]):
    if(fc_players['fb_ID'][i
# Zarraga not found
# Dani Silva not found
# Mitrovic S. not found
# Machin not found
# Pobega not found
# Zerbin not found
# Jajalo not found
# Nicolussi Caviglia not found
# Akpa Akpro not found
# Kone B. not found
# Bohinen not found
# Pisilli not found
# Belardinelli not found
# Kaba not found
# Zeroli not found
# Buchanan T. not found
# Adzic not found
# Liberali not found
# Doumbia I. not found
# Byar not found
# Osimhen not found
# Scamacca not found
# Lookman not found
# Gudmundsson A. not found
# Gonzalez N. not found
# Chiesa not found
# Pinamonti not found
# Sanchez not found
# Pohjanpalo not found
# Yildiz not found
# Dia not found
# Milik not found
# Djuric not found
# Beltran L. not found
# Benedyczak not found
# Ekuban not found
# Arnautovic not found
# Gytkjaer not found
# Tavsan not found
# Bravo not found
# Correa not found
# Pellegri not found
# Success not found
# Shpendi S. not found
# Pizarro not found
# Partipilo not found
# Burnete not found
# Cruz not found
# Camarda not found
# Ankeye not found
# Mutandwa not found
# Joao Costa not found
# Jasim not found
# Charpentier not found

# %%
fc_players
# Out:
#        id  r         name      team      surname initial  fb_ID
# 0    2428  P       Sommer     Inter       Sommer            325
# 1    5876  P  Di Gregorio  Juventus     Gregorio            310
# 2    4312  P      Maignan     Milan      Maignan            314
# 3     572  P        Meret    Napoli        Meret            315
# 4    5841  P       Svilar      Roma       Svilar            327
# ..    ... ..          ...       ...          ...     ...    ...
# 511  6598  A     Mutandwa  Cagliari     Mutandwa             -1
# 512  6603  A   Joao Costa      Roma        Costa             -1
# 513  6648  A        Jasim      Como        Jasim             -1
# 514  6670  A  Charpentier     Parma  Charpentier             -1
# 515  6822  A      Ekhator     Genoa      Ekhator             97
#
# [516 rows x 7 columns]

# %% [markdown]
# Populate players dataset with stats from FBref, for outfield players and goalkeepers

# %%
#Data for Outfield players
columns_to_copy = outfield_players.columns[4:]

fc_players[columns_to_copy] = 0

for i in range(fc_players.shape[0]):
    if(fc_players['fb_ID'][i] != -1 and fc_players['r'][i] != 'P'):
         for j in range(columns_to_copy.shape[0]):
            #fc_players[columns_to_copy[j]][i] = outfield_players[columns_to_copy[j]][fc_players['fb_ID'][i]]
            fc_players.loc[i, columns_to_copy[j]] = outfield_players.loc[fc_players['fb_ID'][i], columns_to_copy[j]]
# Out:
# C:\Users\mbolo\AppData\Local\Temp\ipykernel_16188\2053436513.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy] = 0
# C:\Users\mbolo\AppData\Local\Temp\ipykernel_16188\2053436513.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy] = 0
# C:\Users\mbolo\AppData\Local\Temp\ipykernel_16188\2053436513.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy] = 0
# C:\Users\mbolo\AppData\Local\Temp\ipykernel_16188\2053436513.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy] = 0
# C:\Users\mbolo\AppData\Local\Temp\ipykernel_16188\2053436513.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy] = 0
# C:\Users\mbolo\AppData\Local\Temp\ipykernel_16188\2053436513.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy] = 0
# C:\Users\mbolo\AppData\Local\Temp\ipykernel_16188\2053436513.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy] = 0
# C:\Users\mbolo\AppData\Local\Temp\ipykernel_16188\2053436513.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy] = 0
# C:\Users\mbolo\AppData\Local\Temp\ipykernel_16188\2053436513.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy] = 0
# C:\Users\mbolo\AppData\Local\Temp\ipykernel_16188\2053436513.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy] = 0
# C:\Users\mbolo\AppData\Local\Temp\ipykernel_16188\2053436513.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy] = 0
# C:\Users\mbolo\AppData\Local\Temp\ipykernel_16188\2053436513.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy] = 0
# C:\Users\mbolo\AppData\Local\Temp\ipykernel_16188\2053436513.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy] = 0
# C:\Users\mbolo\AppData\Local\Temp\ipykernel_16188\2053436513.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy] = 0
# C:\Users\mbolo\AppData\Local\Temp\ipykernel_16188\2053436513.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy] = 0
# C:\Users\mbolo\AppData\Local\Temp\ipykernel_16188\2053436513.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy] = 0

# %%
keeper_players.columns[4:]
# Out:
# Index(['age', 'birth_year', 'gk_games', 'gk_games_starts', 'gk_minutes',
#        'gk_goals_against', 'gk_goals_against_per90',
#        'gk_shots_on_target_against', 'gk_saves', 'gk_save_pct', 'gk_wins',
#        'gk_ties', 'gk_losses', 'gk_clean_sheets', 'gk_clean_sheets_pct',
#        'gk_pens_att', 'gk_pens_allowed', 'gk_pens_saved', 'gk_pens_missed',
#        'minutes_90s', 'gk_free_kick_goals_against',
#        'gk_corner_kick_goals_against', 'gk_own_goals_against', 'gk_psxg',
#        'gk_psnpxg_per_shot_on_target_against', 'gk_psxg_net',
#        'gk_psxg_net_per90', 'gk_passes_completed_launched',
#        'gk_passes_launched', 'gk_passes_pct_launched', 'gk_passes',
#        'gk_passes_throws', 'gk_pct_passes_launched', 'gk_passes_length_avg',
#        'gk_goal_kicks', 'gk_pct_goal_kicks_launched',
#        'gk_goal_kick_length_avg', 'gk_crosses', 'gk_crosses_stopped',
#        'gk_crosses_stopped_pct', 'gk_def_actions_outside_pen_area',
#        'gk_def_actions_outside_pen_area_per90', 'gk_avg_distance_def_actions'],
#       dtype='object')

# %%
#Data for Keepers
columns_to_copy = keeper_players.columns[4:]

fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year

delta_k = outfield_players.shape[0]

for i in range(fc_players.shape[0]):
    if(fc_players['fb_ID'][i] != -1 and fc_players['r'][i] == 'P'):
         for j in range(columns_to_copy.shape[0]):
            #fc_players[columns_to_copy[j]][i] = keeper_players[columns_to_copy[j]][fc_players['fb_ID'][i] - delta_k]
            fc_players.loc[i, columns_to_copy[j]] = keeper_players.loc[fc_players['fb_ID'][i] - delta_k, columns_to_copy[j]]
# Out:
# C:\Users\mbolo\AppData\Local\Temp\ipykernel_16188\127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\mbolo\AppData\Local\Temp\ipykernel_16188\127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\mbolo\AppData\Local\Temp\ipykernel_16188\127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\mbolo\AppData\Local\Temp\ipykernel_16188\127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\mbolo\AppData\Local\Temp\ipykernel_16188\127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\mbolo\AppData\Local\Temp\ipykernel_16188\127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\mbolo\AppData\Local\Temp\ipykernel_16188\127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\mbolo\AppData\Local\Temp\ipykernel_16188\127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\mbolo\AppData\Local\Temp\ipykernel_16188\127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\mbolo\AppData\Local\Temp\ipykernel_16188\127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\mbolo\AppData\Local\Temp\ipykernel_16188\127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\mbolo\AppData\Local\Temp\ipykernel_16188\127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\mbolo\AppData\Local\Temp\ipykernel_16188\127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\mbolo\AppData\Local\Temp\ipykernel_16188\127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\mbolo\AppData\Local\Temp\ipykernel_16188\127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\mbolo\AppData\Local\Temp\ipykernel_16188\127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\mbolo\AppData\Local\Temp\ipykernel_16188\127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\mbolo\AppData\Local\Temp\ipykernel_16188\127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\mbolo\AppData\Local\Temp\ipykernel_16188\127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\mbolo\AppData\Local\Temp\ipykernel_16188\127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\mbolo\AppData\Local\Temp\ipykernel_16188\127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\mbolo\AppData\Local\Temp\ipykernel_16188\127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\mbolo\AppData\Local\Temp\ipykernel_16188\127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\mbolo\AppData\Local\Temp\ipykernel_16188\127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\mbolo\AppData\Local\Temp\ipykernel_16188\127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\mbolo\AppData\Local\Temp\ipykernel_16188\127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\mbolo\AppData\Local\Temp\ipykernel_16188\127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\mbolo\AppData\Local\Temp\ipykernel_16188\127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\mbolo\AppData\Local\Temp\ipykernel_16188\127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\mbolo\AppData\Local\Temp\ipykernel_16188\127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\mbolo\AppData\Local\Temp\ipykernel_16188\127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\mbolo\AppData\Local\Temp\ipykernel_16188\127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\mbolo\AppData\Local\Temp\ipykernel_16188\127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\mbolo\AppData\Local\Temp\ipykernel_16188\127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\mbolo\AppData\Local\Temp\ipykernel_16188\127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\mbolo\AppData\Local\Temp\ipykernel_16188\127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\mbolo\AppData\Local\Temp\ipykernel_16188\127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\mbolo\AppData\Local\Temp\ipykernel_16188\127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\mbolo\AppData\Local\Temp\ipykernel_16188\127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\mbolo\AppData\Local\Temp\ipykernel_16188\127446819.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year

# %%
fc_players
# Out:
#        id  r         name      team      surname initial  fb_ID     age  \
# 0    2428  P       Sommer     Inter       Sommer            325  35-250
# 1    5876  P  Di Gregorio  Juventus     Gregorio            310  27-027
# 2    4312  P      Maignan     Milan      Maignan            314  29-051
# 3     572  P        Meret    Napoli        Meret            315  27-154
# 4    5841  P       Svilar      Roma       Svilar            327  24-362
# ..    ... ..          ...       ...          ...     ...    ...     ...
# 511  6598  A     Mutandwa  Cagliari     Mutandwa             -1       0
# 512  6603  A   Joao Costa      Roma        Costa             -1       0
# 513  6648  A        Jasim      Como        Jasim             -1       0
# 514  6670  A  Charpentier     Parma  Charpentier             -1       0
# 515  6822  A      Ekhator     Genoa      Ekhator             97  17-286
#
#      birth_year  games  ...  gk_passes_length_avg  gk_goal_kicks  \
# 0          1988      0  ...                  20.1              4
# 1          1997      0  ...                  24.7              7
# 2          1995      0  ...                  24.4              2
# 3          1997      0  ...                  21.2              8
# 4          1999      0  ...                  26.3              8
# ..          ...    ...  ...                   ...            ...
# 511           0      0  ...                   0.0              0
# 512           0      0  ...                   0.0              0
# 513           0      0  ...                   0.0              0
# 514           0      0  ...                   0.0              0
# 515        2006      1  ...                   0.0              0
#
#      gk_pct_goal_kicks_launched  gk_goal_kick_length_avg  gk_crosses  \
# 0                          25.0                     30.0          11
# 1                          42.9                     37.3          10
# 2                          50.0                     41.0           7
# 3                          25.0                     24.3           5
# 4                          62.5                     51.6          13
# ..                          ...                      ...         ...
# 511                         0.0                      0.0           0
# 512                         0.0                      0.0           0
# 513                         0.0                      0.0           0
# 514                         0.0                      0.0           0
# 515                         0.0                      0.0           0
#
#      gk_crosses_stopped  gk_crosses_stopped_pct  \
# 0                     0                     0.0
# 1                     1                    10.0
# 2                     1                    14.3
# 3                     1                    20.0
# 4                     0                     0.0
# ..                  ...                     ...
# 511                   0                     0.0
# 512                   0                     0.0
# 513                   0                     0.0
# 514                   0                     0.0
# 515                   0                     0.0
#
#      gk_def_actions_outside_pen_area  gk_def_actions_outside_pen_area_per90  \
# 0                                  1                                      1
# 1                                  0                                      0
# 2                                  4                                      4
# 3                                  2                                      2
# 4                                  0                                      0
# ..                               ...                                    ...
# 511                                0                                      0
# 512                                0                                      0
# 513                                0                                      0
# 514                                0                                      0
# 515                                0                                      0
#
#      gk_avg_distance_def_actions
# 0                           21.5
# 1                            4.0
# 2                           22.0
# 3                           21.2
# 4                           15.0
# ..                           ...
# 511                          0.0
# 512                          0.0
# 513                          0.0
# 514                          0.0
# 515                          0.0
#
# [516 rows x 158 columns]

# %% [markdown]
# Load votes database, to add data to players database (mean vote and its standard deviation)

# %%
import numpy as np

votes = pd.read_excel('mid_outputs/players_votes.xlsx', index_col = 0)

# %% [markdown]
# Compute the average Serie A Goal Keeper mean vote and vote std

# %%
min_votes = 3 # TO BE UPDATED WHEN SERIE A HAS MORE CALENDAR WEEKS PLAYED

perf_df_P = pd.DataFrame(columns = ['vote_avg', 'vote_std'])

for i in range(fc_players.shape[0]): 
    if(fc_players.loc[i]['r'] == 'P'):
        v = np.array([])
        for j in range(votes.shape[0]):
            if(fc_players['name'][i] == votes['player'][j]):
                v = np.append(v, votes['vote'][j])

        if(v.shape[0] >= min_votes - 1):
            row_df = pd.DataFrame(data = [[np.mean(v), np.std(v)]], columns = perf_df_P.columns)
            perf_df_P = pd.concat([perf_df_P, row_df], ignore_index = True)


print(perf_df_P.mean())

perf_df_P
# Out:
# vote_avg    NaN
# vote_std    NaN
# dtype: object
# Empty DataFrame
# Columns: [vote_avg, vote_std]
# Index: []

# %% [markdown]
# Add to players data their mean vote (and its standard deviation).
#
# For players who don't have a minimum amount of games, more data to reach this value is computed, according to the average Serie A player vote (and std). For goalkeepers, this values are different.

# %%
min_votes = 3 # TO BE UPDATED WHEN SERIE A HAS MORE CALENDAR WEEKS PLAYED

#outfield players
mean_def = 6
std_def = 0.58

#goalkeepers
mean_def_P = 6.22
std_def_P = 0.43


perf_df = pd.DataFrame(columns = ['vote_avg', 'vote_std'])

for i in range(fc_players.shape[0]):
    v = np.array([])
    for j in range(votes.shape[0]):
        if(fc_players['name'][i] == votes['player'][j]):
            v = np.append(v, votes['vote'][j])
    
    mean_def_i = mean_def
    std_def_i = std_def
    
    if(fc_players['r'][i] == 'P'):
        mean_def_i = mean_def_P
        std_def_i = std_def_P
        
    if(v.shape[0] < min_votes):
         for k in range(min_votes - v.shape[0]):
            v = np.append( v, np.random.normal(mean_def_i, std_def_i) )
    
    row_df = pd.DataFrame(data = [[np.mean(v), np.std(v)]], columns = perf_df.columns)
    perf_df = pd.concat([perf_df, row_df], ignore_index = True)
    
perf_df
# Out:
#      vote_avg  vote_std
# 0    6.389434  0.352443
# 1    5.957350  0.502698
# 2    6.016327  0.415725
# 3    6.278914  0.426042
# 4    5.695154  0.617236
# ..        ...       ...
# 511  5.926173  0.124456
# 512  6.071242  0.602993
# 513  6.436300  0.475408
# 514  6.294181  0.432765
# 515  5.648701  0.238849
#
# [516 rows x 2 columns]

# %%
fc_players = pd.concat([fc_players, perf_df], axis = 1)

fc_players
# Out:
#        id  r         name      team      surname initial  fb_ID     age  \
# 0    2428  P       Sommer     Inter       Sommer            325  35-250
# 1    5876  P  Di Gregorio  Juventus     Gregorio            310  27-027
# 2    4312  P      Maignan     Milan      Maignan            314  29-051
# 3     572  P        Meret    Napoli        Meret            315  27-154
# 4    5841  P       Svilar      Roma       Svilar            327  24-362
# ..    ... ..          ...       ...          ...     ...    ...     ...
# 511  6598  A     Mutandwa  Cagliari     Mutandwa             -1       0
# 512  6603  A   Joao Costa      Roma        Costa             -1       0
# 513  6648  A        Jasim      Como        Jasim             -1       0
# 514  6670  A  Charpentier     Parma  Charpentier             -1       0
# 515  6822  A      Ekhator     Genoa      Ekhator             97  17-286
#
#      birth_year  games  ...  gk_pct_goal_kicks_launched  \
# 0          1988      0  ...                        25.0
# 1          1997      0  ...                        42.9
# 2          1995      0  ...                        50.0
# 3          1997      0  ...                        25.0
# 4          1999      0  ...                        62.5
# ..          ...    ...  ...                         ...
# 511           0      0  ...                         0.0
# 512           0      0  ...                         0.0
# 513           0      0  ...                         0.0
# 514           0      0  ...                         0.0
# 515        2006      1  ...                         0.0
#
#      gk_goal_kick_length_avg  gk_crosses  gk_crosses_stopped  \
# 0                       30.0          11                   0
# 1                       37.3          10                   1
# 2                       41.0           7                   1
# 3                       24.3           5                   1
# 4                       51.6          13                   0
# ..                       ...         ...                 ...
# 511                      0.0           0                   0
# 512                      0.0           0                   0
# 513                      0.0           0                   0
# 514                      0.0           0                   0
# 515                      0.0           0                   0
#
#      gk_crosses_stopped_pct  gk_def_actions_outside_pen_area  \
# 0                       0.0                                1
# 1                      10.0                                0
# 2                      14.3                                4
# 3                      20.0                                2
# 4                       0.0                                0
# ..                      ...                              ...
# 511                     0.0                                0
# 512                     0.0                                0
# 513                     0.0                                0
# 514                     0.0                                0
# 515                     0.0                                0
#
#      gk_def_actions_outside_pen_area_per90  gk_avg_distance_def_actions  \
# 0                                        1                         21.5
# 1                                        0                          4.0
# 2                                        4                         22.0
# 3                                        2                         21.2
# 4                                        0                         15.0
# ..                                     ...                          ...
# 511                                      0                          0.0
# 512                                      0                          0.0
# 513                                      0                          0.0
# 514                                      0                          0.0
# 515                                      0                          0.0
#
#      vote_avg  vote_std
# 0    6.389434  0.352443
# 1    5.957350  0.502698
# 2    6.016327  0.415725
# 3    6.278914  0.426042
# 4    5.695154  0.617236
# ..        ...       ...
# 511  5.926173  0.124456
# 512  6.071242  0.602993
# 513  6.436300  0.475408
# 514  6.294181  0.432765
# 515  5.648701  0.238849
#
# [516 rows x 160 columns]

# %%
GK_GAMES_COLUMN = 118

fc_players.columns[GK_GAMES_COLUMN]

# check it if is 'gk_games'
# Out:
# 'gk_games'

# %% [markdown]
# For goalkeepers who didn't play a miminum amount of games, data is weightly averaged with one of the main goalkeeper of their same team.

# %%
min_gk_games = 3 # TO BE UPDATED WHEN SERIE A HAS MORE CALENDAR WEEKS PLAYED

fc_players_newgk = fc_players.copy()

columns_to_avg = fc_players.columns[GK_GAMES_COLUMN:] # from gk_games to end

for i in range(fc_players.shape[0]):
    if(fc_players['r'][i] == 'P'):
        if(fc_players['gk_games'][i] < min_gk_games):
            for j in range(fc_players.shape[0]):
                if(fc_players['team'][i] == fc_players['team'][j] and fc_players['gk_games'][j] >= min_gk_games):
                    break
                    
            weight = 1 - (min_gk_games - fc_players['gk_games'][i]) / min_gk_games
            
            fc_players_newgk.at[i, columns_to_avg] = fc_players.loc[i][columns_to_avg] * weight + (1 - weight) * fc_players.loc[j][columns_to_avg]
            
            print(fc_players['name'][i] + ', ' + str(weight))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: 'Index(['gk_games', 'gk_games_starts', 'gk_minutes', 'gk_goals_against',
#        'gk_goals_against_per90', 'gk_shots_on_target_against', 'gk_saves',
#        'gk_save_pct', 'gk_wins', 'gk_ties', 'gk_losses', 'gk_clean_sheets',
#        'gk_clean_sheets_pct', 'gk_pens_att', 'gk_pens_allowed',
#        'gk_pens_saved', 'gk_pens_missed', 'gk_free_kick_goals_against',
#        'gk_corner_kick_goals_against', 'gk_own_goals_against', 'gk_psxg',
#        'gk_psnpxg_per_shot_on_target_against', 'gk_psxg_net',
#        'gk_psxg_net_per90', 'gk_passes_completed_launched',
#        'gk_passes_launched', 'gk_passes_pct_launched', 'gk_passes',
#        'gk_passes_throws', 'gk_pct_passes_launched', 'gk_passes_length_avg',
#        'gk_goal_kicks', 'gk_pct_goal_kicks_launched',
#        'gk_goal_kick_length_avg', 'gk_crosses', 'gk_crosses_stopped',
#        'gk_crosses_stopped_pct', 'gk_def_actions_outside_pen_area',
#        'gk_def_actions_outside_pen_area_per90', 'gk_avg_distance_def_actions',
#        'vote_avg', 'vote_std'],
#       dtype='object')' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4179, in DataFrame._set_value(self, index, col, value, takeable)
#    4178 else:
# -> 4179     icol = self.columns.get_loc(col)
#    4180     iindex = self.index.get_loc(index)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3660, in Index.get_loc(self, key)
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
# -> 3660     self._check_indexing_error(key)
#    3661     raise
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5737, in Index._check_indexing_error(self, key)
#    5734 if not is_scalar(key):
#    5735     # if key is not a scalar, directly raise an error (the code below
#    5736     # would convert to numpy arrays and raise later any way) - GH29926
# -> 5737     raise InvalidIndexError(key)
#
# InvalidIndexError: Index(['gk_games', 'gk_games_starts', 'gk_minutes', 'gk_goals_against',
#        'gk_goals_against_per90', 'gk_shots_on_target_against', 'gk_saves',
#        'gk_save_pct', 'gk_wins', 'gk_ties', 'gk_losses', 'gk_clean_sheets',
#        'gk_clean_sheets_pct', 'gk_pens_att', 'gk_pens_allowed',
#        'gk_pens_saved', 'gk_pens_missed', 'gk_free_kick_goals_against',
#        'gk_corner_kick_goals_against', 'gk_own_goals_against', 'gk_psxg',
#        'gk_psnpxg_per_shot_on_target_against', 'gk_psxg_net',
#        'gk_psxg_net_per90', 'gk_passes_completed_launched',
#        'gk_passes_launched', 'gk_passes_pct_launched', 'gk_passes',
#        'gk_passes_throws', 'gk_pct_passes_launched', 'gk_passes_length_avg',
#        'gk_goal_kicks', 'gk_pct_goal_kicks_launched',
#        'gk_goal_kick_length_avg', 'gk_crosses', 'gk_crosses_stopped',
#        'gk_crosses_stopped_pct', 'gk_def_actions_outside_pen_area',
#        'gk_def_actions_outside_pen_area_per90', 'gk_avg_distance_def_actions',
#        'vote_avg', 'vote_std'],
#       dtype='object')
#
# The above exception was the direct cause of the following exception:
#
# InvalidIndexError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16188\925074866.py in ?()
#      12                     break
#      13
#      14             weight = 1 - (min_gk_games - fc_players['gk_games'][i]) / min_gk_games
#      15
# ---> 16             fc_players_newgk.at[i, columns_to_avg] = fc_players.loc[i][columns_to_avg] * weight + (1 - weight) * fc_players.loc[j][columns_to_avg]
#      17
#      18             print(fc_players['name'][i] + ', ' + str(weight))
#      19
#
# ~\anaconda3\Lib\site-packages\pandas\core\indexing.py in ?(self, key, value)
#    2426
#    2427             self.obj.loc[key] = value
#    2428             return
#    2429
# -> 2430         return super().__setitem__(key, value)
#
# ~\anaconda3\Lib\site-packages\pandas\core\indexing.py in ?(self, key, value)
#    2382         key = list(self._convert_key(key))
#    2383         if len(key) != self.ndim:
#    2384             raise ValueError("Not enough indexers for scalar access (setting)!")
#    2385
# -> 2386         self.obj._set_value(*key, value=value, takeable=self._takeable)
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, index, col, value, takeable)
#    4195
#    4196         except InvalidIndexError as ii_err:
#    4197             # GH48729: Seems like you are trying to assign a value to a
#    4198             # row when only scalar options are permitted
# -> 4199             raise InvalidIndexError(
#    4200                 f"You can only assign a scalar value not a {type(value)}"
#    4201             ) from ii_err
#
# InvalidIndexError: You can only assign a scalar value not a <class 'pandas.core.series.Series'>

# %%
fc_players = fc_players_newgk

fc_players
# Out:
#        id  r         name      team      surname initial  fb_ID     age  \
# 0    2428  P       Sommer     Inter       Sommer            325  35-250
# 1    5876  P  Di Gregorio  Juventus     Gregorio            310  27-027
# 2    4312  P      Maignan     Milan      Maignan            314  29-051
# 3     572  P        Meret    Napoli        Meret            315  27-154
# 4    5841  P       Svilar      Roma       Svilar            327  24-362
# ..    ... ..          ...       ...          ...     ...    ...     ...
# 511  6598  A     Mutandwa  Cagliari     Mutandwa             -1       0
# 512  6603  A   Joao Costa      Roma        Costa             -1       0
# 513  6648  A        Jasim      Como        Jasim             -1       0
# 514  6670  A  Charpentier     Parma  Charpentier             -1       0
# 515  6822  A      Ekhator     Genoa      Ekhator             97  17-286
#
#      birth_year  games  ...  gk_pct_goal_kicks_launched  \
# 0          1988      0  ...                        25.0
# 1          1997      0  ...                        42.9
# 2          1995      0  ...                        50.0
# 3          1997      0  ...                        25.0
# 4          1999      0  ...                        62.5
# ..          ...    ...  ...                         ...
# 511           0      0  ...                         0.0
# 512           0      0  ...                         0.0
# 513           0      0  ...                         0.0
# 514           0      0  ...                         0.0
# 515        2006      1  ...                         0.0
#
#      gk_goal_kick_length_avg  gk_crosses  gk_crosses_stopped  \
# 0                       30.0          11                   0
# 1                       37.3          10                   1
# 2                       41.0           7                   1
# 3                       24.3           5                   1
# 4                       51.6          13                   0
# ..                       ...         ...                 ...
# 511                      0.0           0                   0
# 512                      0.0           0                   0
# 513                      0.0           0                   0
# 514                      0.0           0                   0
# 515                      0.0           0                   0
#
#      gk_crosses_stopped_pct  gk_def_actions_outside_pen_area  \
# 0                       0.0                                1
# 1                      10.0                                0
# 2                      14.3                                4
# 3                      20.0                                2
# 4                       0.0                                0
# ..                      ...                              ...
# 511                     0.0                                0
# 512                     0.0                                0
# 513                     0.0                                0
# 514                     0.0                                0
# 515                     0.0                                0
#
#      gk_def_actions_outside_pen_area_per90  gk_avg_distance_def_actions  \
# 0                                        1                         21.5
# 1                                        0                          4.0
# 2                                        4                         22.0
# 3                                        2                         21.2
# 4                                        0                         15.0
# ..                                     ...                          ...
# 511                                      0                          0.0
# 512                                      0                          0.0
# 513                                      0                          0.0
# 514                                      0                          0.0
# 515                                      0                          0.0
#
#      vote_avg  vote_std
# 0    6.389434  0.352443
# 1    5.957350  0.502698
# 2    6.016327  0.415725
# 3    6.278914  0.426042
# 4    5.695154  0.617236
# ..        ...       ...
# 511  5.926173  0.124456
# 512  6.071242  0.602993
# 513  6.436300  0.475408
# 514  6.294181  0.432765
# 515  5.648701  0.238849
#
# [516 rows x 160 columns]

# %% [markdown]
# Save to file.

# %%
fc_players.to_excel('mid_outputs/players_stats.xlsx')
