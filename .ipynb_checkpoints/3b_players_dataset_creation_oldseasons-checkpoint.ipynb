# %% [markdown]
# players__dataset_creation code for past seasons
#
# Select the season in season variable, and repeat the code if needed

# %%
season = '2324'

# %%
import pandas as pd

# %%
rcsv = pd.read_csv('fbref_data/season' + season + '/outfield_players.csv')   
outfield_players = pd.DataFrame(rcsv)

rcsv = pd.read_csv('fbref_data/season' + season + '/keepers_players.csv')   
keeper_players = pd.DataFrame(rcsv)

# %%
players = pd.concat(   [ outfield_players[['player', 'team']], keeper_players[['player', 'team']] ], axis = 0, ignore_index = True)
keepers_ID = len(outfield_players)
players
# Out:
#                  player        team
# 0         Tammy Abraham        Roma
# 1      Francesco Acerbi       Inter
# 2           Yacine Adli       Milan
# 3      Michel Aebischer     Bologna
# 4         Lucien Agoume       Inter
# ..                  ...         ...
# 662    Marco Sportiello       Milan
# 663         Mile Svilar        Roma
# 664   Wojciech Szczęsny    Juventus
# 665  Pietro Terracciano  Fiorentina
# 666      Stefano Turati   Frosinone
#
# [667 rows x 2 columns]

# %%
import unicodedata

def normalize_name(input_str):
    nfkd_form = unicodedata.normalize('NFKD', input_str)
    only_ascii = nfkd_form.encode('ASCII', 'ignore')
    return only_ascii.decode('utf-8')

# %%
players['surname'] = players['player']
players['initial'] = players['player']

for i in range(players.shape[0]):
    players['surname'][i] = players['surname'][i].split(' ')[-1]
    players['surname'][i] = normalize_name(players['surname'][i]).replace('\'', '')
    
    
    players['initial'][i] = players['player'][i][0]

# %%
print(players[['player', 'surname']].to_string())
# Out:
#                          player           surname
# 0                 Tammy Abraham           Abraham
# 1              Francesco Acerbi            Acerbi
# 2                   Yacine Adli              Adli
# 3              Michel Aebischer         Aebischer
# 4                 Lucien Agoume            Agoume
# 5                    Marley Aké               Ake
# 6          Ebenezer Akinsanmiro       Akinsanmiro
# 7        Jean-Daniel Akpa-Akpro        Akpa-Akpro
# 8            David Akpan Ankeye            Ankeye
# 9                  Luis Alberto           Alberto
# 10               Carlos Alcaraz           Alcaraz
# 11              Pontus Almqvist          Almqvist
# 12             Lorenzo Amatucci          Amatucci
# 13                 Bruno Amione            Amione
# 14              Felipe Anderson          Anderson
# 15                     Angeliño          Angelino
# 16                Houssem Aouar             Aouar
# 17                Simone Aresti            Aresti
# 18             Marko Arnautović        Arnautovic
# 19             Kristjan Asllani           Asllani
# 20                  Emil Audero            Audero
# 21              Tommaso Augello           Augello
# 22               Carlos Augusto           Augusto
# 23           Yann Aurel Bisseck           Bisseck
# 24                Sardar Azmoun            Azmoun
# 25                   Paulo Azzi              Azzi
# 26           Oussama El Azzouzi           Azzouzi
# 27                 Milan Badelj            Badelj
# 28                   Jaime Báez              Baez
# 29             Nicola Bagnolini         Bagnolini
# 30                Nedim Bajrami           Bajrami
# 31               Mitchel Bakker            Bakker
# 32             Tommaso Baldanzi          Baldanzi
# 33             Tommaso Baldanzi          Baldanzi
# 34                 Lameck Banda             Banda
# 35              Daniel Bandeira          Bandeira
# 36                  Mattia Bani              Bani
# 37                Antonín Barák             Barak
# 38               Nicolò Barella           Barella
# 39             Enzo Barrenechea       Barrenechea
# 40            Davide Bartesaghi        Bartesaghi
# 41         Federico Baschirotto       Baschirotto
# 42                   Toma Bašić             Basic
# 43           Alessandro Bastoni           Bastoni
# 44               Simone Bastoni           Bastoni
# 45               Reda Belahyane         Belahyane
# 46              Raoul Bellanova         Bellanova
# 47               Andrea Belotti           Belotti
# 48               Andrea Belotti           Belotti
# 49                Lucas Beltrán           Beltran
# 50              Ismaël Bennacer          Bennacer
# 51             Domenico Berardi           Berardi
# 52          Bartosz Bereszyński       Bereszynski
# 53                Etrit Berisha           Berisha
# 54                Medon Berisha           Berisha
# 55    Victor Bernth Kristiansen       Kristiansen
# 56                         Beto              Beto
# 57              Davide Bettella          Bettella
# 58                  Sam Beukema           Beukema
# 59                   Jaka Bijol             Bijol
# 60               El Bilal Touré             Toure
# 61            Cristiano Biraghi           Biraghi
# 62              Davide Biraschi          Biraschi
# 63           Samuele Birindelli        Birindelli
# 64                  Alexis Blin              Blin
# 65               Jérôme Boateng           Boateng
# 66                 Emil Bohinen           Bohinen
# 67                 Emil Bohinen           Bohinen
# 68                Daniel Boloca            Boloca
# 69          Giacomo Bonaventura       Bonaventura
# 70           Federico Bonazzoli         Bonazzoli
# 71                 Warren Bondo             Bondo
# 72            Giovanni Bonfanti          Bonfanti
# 73               Kevin Bonifazi          Bonifazi
# 74               Kevin Bonifazi          Bonifazi
# 75             Gennaro Borrelli          Borrelli
# 76                 Erik Botheim           Botheim
# 77               Mehdi Bourabia          Bourabia
# 78                 Edoardo Bove              Bove
# 79             Domagoj Bradarić          Bradaric
# 80                Josip Brekalo           Brekalo
# 81               Gleison Bremer            Bremer
# 82                      Brenner           Brenner
# 83            Marco Brescianini       Brescianini
# 84                  Dylan Bronn             Bronn
# 85               Tajon Buchanan          Buchanan
# 86        Alessandro Buongiorno        Buongiorno
# 87        Rareș-Cătălin Burnete           Burnete
# 88                Jovane Cabral            Cabral
# 89              Liberato Cacace            Cacace
# 90                 Jens Cajuste           Cajuste
# 91              Davide Calabria          Calabria
# 92           Riccardo Calafiori         Calafiori
# 93               Mattia Caldara           Caldara
# 94               Luca Caldirola         Caldirola
# 95             Hakan Çalhanoğlu        Calhanoglu
# 96            Francesco Camarda           Camarda
# 97             Nicolò Cambiaghi         Cambiaghi
# 98              Andrea Cambiaso          Cambiaso
# 99           Matteo Cancellieri       Cancellieri
# 100            Antonio Candreva          Candreva
# 101               Luigi Canotto           Canotto
# 102            Gianluca Caprari           Caprari
# 103                Elia Caprile           Caprile
# 104            Francesco Caputo            Caputo
# 105              Andrea Carboni           Carboni
# 106            Valentin Carboni           Carboni
# 107           Marco Carnesecchi       Carnesecchi
# 108               Nicolò Casale            Casale
# 109               Giuseppe Caso              Caso
# 110        Valentín Castellanos       Castellanos
# 111             Samu Castillejo        Castillejo
# 112             Santiago Castro            Castro
# 113         Gaetano Castrovilli       Castrovilli
# 114              Danilo Cataldi           Cataldi
# 115                  Emil Ceide             Ceide
# 116                  Zeki Çelik             Celik
# 117             Fabien Centonze          Centonze
# 118          Michele Cerofolini        Cerofolini
# 119               Alberto Cerri             Cerri
# 120              Leonardo Cerri             Cerri
# 121                     Charlys           Charlys
# 122              Walid Cheddira          Cheddira
# 123             Federico Chiesa            Chiesa
# 124          Oliver Christensen       Christensen
# 125            Samuel Chukwueze         Chukwueze
# 126              Alphadjo Cissè             Cisse
# 127           Giorgio Cittadini         Cittadini
# 128           Giorgio Cittadini         Cittadini
# 129             Patrick Ciurria           Ciurria
# 130             Lorenzo Colombo           Colombo
# 131              Andrea Colpani           Colpani
# 132              Pietro Comuzzo           Comuzzo
# 133             Andrea Consigli          Consigli
# 134   Nikita Contini Baranovsky        Baranovsky
# 135               Diego Coppola           Coppola
# 136             Tommaso Corazza           Corazza
# 137             Jeppe Corfitzen         Corfitzen
# 138              Giacomo Corona            Corona
# 139                  João Costa             Costa
# 140               Benoît Costil            Costil
# 141           Lassana Coulibaly         Coulibaly
# 142           Mamadou Coulibaly         Coulibaly
# 143              Alessio Cragno            Cragno
# 144             Bryan Cristante         Cristante
# 145                   Juan Cruz              Cruz
# 146               Juan Cuadrado          Cuadrado
# 147                 Marvin Cuni              Cuni
# 148           Danilo D'Ambrosio         DAmbrosio
# 149            Flavius Daniliuc          Daniliuc
# 150                      Danilo            Danilo
# 151              Matteo Darmian           Darmian
# 152            Juan David Cabal             Cabal
# 153                Keinan Davis             Davis
# 154            Paweł Dawidowicz        Dawidowicz
# 155        Charles De Ketelaere         Ketelaere
# 156           Mattia De Sciglio           Sciglio
# 157        Lorenzo De Silvestri         Silvestri
# 158              Koni De Winter            Winter
# 159             Grégoire Defrel            Defrel
# 160           Alessandro Deiola            Deiola
# 161       Alessandro Dellavalle        Dellavalle
# 162                 Diego Demme             Demme
# 163          Leander Dendoncker        Dendoncker
# 164               Mattia Destro            Destro
# 165       Federico Di Francesco         Francesco
# 166         Raffaele Di Gennaro           Gennaro
# 167         Michele Di Gregorio          Gregorio
# 168         Giovanni Di Lorenzo           Lorenzo
# 169         Alessandro Di Pardo             Pardo
# 170                 Boulaye Dia               Dia
# 171            Federico Dimarco           Dimarco
# 172                 Tiago Djaló             Djalo
# 173                Koffi Djidji            Djidji
# 174              Berat Djimsiti          Djimsiti
# 175                        Dodô              Dodo
# 176                   Josh Doig              Doig
# 177                   Josh Doig              Doig
# 178           Nicolás Domínguez         Dominguez
# 179               Giulio Donati            Donati
# 180               Patrick Dorgu             Dorgu
# 181             Alberto Dossena           Dossena
# 182               Radu Drăgușin          Dragusin
# 183                 Ondrej Duda              Duda
# 184             Denzel Dumfries          Dumfries
# 185               Alfred Duncan            Duncan
# 186                Paulo Dybala            Dybala
# 187               Festy Ebosele           Ebosele
# 188                 Enzo Ebosse            Ebosse
# 189              Tyronne Ebuehi            Ebuehi
# 190                     Éderson           Ederson
# 191           Kingsley Ehizibue          Ehizibue
# 192              Emmanuel Ekong             Ekong
# 193                Caleb Ekuban            Ekuban
# 194                  Elif Elmas             Elmas
# 195                Martin Erlic             Erlic
# 196            Giovanni Fabbian           Fabbian
# 197              Nicolò Fagioli           Fagioli
# 198           Wladimiro Falcone           Falcone
# 199              Davide Faraoni           Faraoni
# 200              Davide Faraoni           Faraoni
# 201              Federico Fazio             Fazio
# 202              Jacopo Fazzini           Fazzini
# 203              Lewis Ferguson          Ferguson
# 204             Andrea Ferraris          Ferraris
# 527              Chris Smalling          Smalling
# 528               Andrea Sodero            Sodero
# 529               Ola Solbakken         Solbakken
# 530           Daniele Sommariva         Sommariva
# 531                 Yann Sommer            Sommer
# 532               Brandon Soppy             Soppy
# 533       Alessandro Sorrentino        Sorrentino
# 534             Riccardo Sottil            Sottil
# 535                Matìas Soulé             Soule
# 536                 Djed Spence            Spence
# 537         Leonardo Spinazzola        Spinazzola
# 538            Marco Sportiello        Sportiello
# 539            Trivante Stewart           Stewart
# 540           Gabriel Strefezza         Strefezza
# 541             Kevin Strootman         Strootman
# 542               Isaac Success           Success
# 543            Ibrahim Sulemana          Sulemana
# 544                Tomáš Suslov            Suslov
# 545                 Mile Svilar            Svilar
# 546             Karol Świderski         Swiderski
# 547           Wojciech Szczęsny          Szczesny
# 548        Przemysław Szymiński         Szyminski
# 549               Adrien Tameze            Tameze
# 550               Elayis Tavsan            Tavsan
# 551               Loum Tchaouna          Tchaouna
# 552          Jackson Tchatchoua        Tchatchoua
# 553         Filippo Terracciano       Terracciano
# 554         Filippo Terracciano       Terracciano
# 555          Pietro Terracciano       Terracciano
# 556             Florian Thauvin           Thauvin
# 557                Malick Thiaw             Thiaw
# 558              Morten Thorsby           Thorsby
# 559         Kristian Thorstvedt        Thorstvedt
# 560               Marcus Thuram            Thuram
# 561              Antonio Tikvić            Tikvic
# 562               Jeremy Toljan            Toljan
# 563                Rafael Tolói             Toloi
# 564               Fikayo Tomori            Tomori
# 565                 Ahmed Touba             Touba
# 566                Chaka Traorè            Traore
# 567              Stefano Turati            Turati
# 568             Kacper Urbanski          Urbanski
# 569             Emanuele Valeri            Valeri
# 570               Johan Vásquez           Vasquez
# 571               Matías Vecino            Vecino
# 572              Lorenzo Venuti            Venuti
# 573                Simone Verdi             Verdi
# 574             Emanuel Vignato           Vignato
# 575             Samuele Vignato           Vignato
# 576                 Matías Viña              Vina
# 577               Rúben Vinagre           Vinagre
# 578               Nicolas Viola             Viola
# 579                 Mattia Viti              Viti
# 580                     Vitinha           Vitinha
# 581              Dušan Vlahović          Vlahovic
# 582               Nikola Vlašić            Vlasic
# 583        Alessandro Vogliacco         Vogliacco
# 584              Mërgim Vojvoda           Vojvoda
# 585            Cristian Volpato           Volpato
# 586              Stefan de Vrij              Vrij
# 587                      Walace            Walace
# 588       Sebastian Walukiewicz       Walukiewicz
# 589                Timothy Weah              Weah
# 590               Shon Weissman          Weissman
# 591            Mateusz Wieteska          Wieteska
# 592                Kenan Yıldız              Yldz
# 593             Mattia Zaccagni          Zaccagni
# 594             Nicola Zalewski          Zalewski
# 595  Andre-Frank Zambo Anguissa          Anguissa
# 596           Alessandro Zanoli            Zanoli
# 597           Alessandro Zanoli            Zanoli
# 598                Duván Zapata            Zapata
# 599                Duván Zapata            Zapata
# 600              Gabriele Zappa             Zappa
# 601           Davide Zappacosta        Zappacosta
# 602                Oier Zarraga           Zarraga
# 603               Jordan Zemura            Zemura
# 604              Alessio Zerbin            Zerbin
# 605              Alessio Zerbin            Zerbin
# 606                Kevin Zeroli            Zeroli
# 607             Piotr Zieliński         Zielinski
# 608                  David Zima              Zima
# 609              Joshua Zirkzee           Zirkzee
# 610                Nadir Zortea            Zortea
# 611                Nadir Zortea            Zortea
# 612            Szymon Żurkowski         Zurkowski
# 613                 Milan Đurić              uric
# 614                 Milan Đurić              uric
# 615            Mateusz Łęgowski           egowski
# 616               Simone Aresti            Aresti
# 617                 Emil Audero            Audero
# 618            Nicola Bagnolini         Bagnolini
# 619               Etrit Berisha           Berisha
# 620                Elia Caprile           Caprile
# 621           Marco Carnesecchi       Carnesecchi
# 622          Michele Cerofolini        Cerofolini
# 623          Oliver Christensen       Christensen
# 624             Andrea Consigli          Consigli
# 625   Nikita Contini Baranovsky        Baranovsky
# 626               Benoît Costil            Costil
# 627              Alessio Cragno            Cragno
# 628         Raffaele Di Gennaro           Gennaro
# 629         Michele Di Gregorio          Gregorio
# 630           Wladimiro Falcone           Falcone
# 631           Vincenzo Fiorillo          Fiorillo
# 632                Luca Gemello           Gemello
# 633           Pierluigi Gollini           Gollini
# 634                Nicola Leali             Leali
# 635                Mike Maignan           Maignan
# 636             Christos Mandas            Mandas
# 637          Tommaso Martinelli        Martinelli
# 638              Josep Martinez          Martinez
# 639                  Alex Meret             Meret
# 640      Vanja Milinković-Savić  Milinkovic-Savic
# 641             Antonio Mirante           Mirante
# 642             Lorenzo Montipò           Montipo
# 643                  Juan Musso             Musso
# 644                   Lapo Nava              Nava
# 645             Guillermo Ochoa             Ochoa
# 646                Maduka Okoye             Okoye
# 647                Rui Patrício          Patricio
# 648              Simone Perilli           Perilli
# 649                Mattia Perin             Perin
# 650             Samuele Perisan           Perisan
# 651             Carlo Pinsoglio         Pinsoglio
# 652               Ivan Provedel          Provedel
# 653             Boris Radunović         Radunovic
# 654           Federico Ravaglia          Ravaglia
# 655             Francesco Rossi             Rossi
# 656              Simone Scuffet           Scuffet
# 657             Marco Silvestri         Silvestri
# 658            Łukasz Skorupski         Skorupski
# 659           Daniele Sommariva         Sommariva
# 660                 Yann Sommer            Sommer
# 661       Alessandro Sorrentino        Sorrentino
# 662            Marco Sportiello        Sportiello
# 663                 Mile Svilar            Svilar
# 664           Wojciech Szczęsny          Szczesny
# 665          Pietro Terracciano       Terracciano
# 666              Stefano Turati            Turati

# %%
rcsv = pd.read_csv('config/name_fix.txt')   
name_fix = pd.DataFrame(rcsv)

for i in range(name_fix.shape[0]):
    for j in range(players.shape[0]):
        if(players['surname'][j].lower() == name_fix['FROM'][i].lower() and players['team'][j].lower() == name_fix['TEAM'][i].lower()):
            players['surname'][j] = name_fix['TO'][i]
            print(name_fix['TO'][i])

name_fix
# Out:
# Ostigard
# Kjaer
# Djuric
# Gudmundsson
# Nissen
#           FROM           TO           TEAM
# 0      stigard     Ostigard         Napoli
# 1      Min-jae          Kim         Napoli
# 2       Hjlund      Hojlund       Atalanta
# 3       Gytkjr     Gytkjaer          Monza
# 4       Carlos      Augusto          Inter
# 5         Mhle       Maehle       Atalanta
# 6          Kjr        Kjaer          Milan
# 7       uricic     Djuricic      Sampdoria
# 8         uric       Djuric  Hellas Verona
# 9       Arthur       Cabral     Fiorentina
# 10    Martinez      Alvarez       Sassuolo
# 11  Gumundsson  Gudmundsson          Genoa
# 12  Kristensen       Nissen           Roma

# %%
fc_data = pd.read_excel('fantacalcio/season' + season + '/Quotazioni_Fantacalcio.xlsx', 'Tutti', header = 1)

fc_players = fc_data [['Id', 'R', 'Nome', 'Squadra']]

fc_players = fc_players.rename(columns = {'Id' : 'id', 'R': 'r', 'Nome' : 'name', 'Squadra' : 'team'})

fc_players['surname'] = fc_players['name']
fc_players['initial'] = fc_players['name']


for i in range(fc_players.shape[0]):
    spl = normalize_name( fc_players['name'][i].replace('\'', '') ).split(' ')
    if('.' in spl[-1]):
        fc_players.loc[i, 'surname'] = spl[-2]
        fc_players.loc[i, 'initial'] = spl[-1][0]
    else:
        fc_players.loc[i, 'surname'] = spl[-1]
        fc_players.loc[i, 'initial'] = ''
    
fc_players
# Out:
#        id  r         name         team    surname initial
# 0    2428  P       Sommer        Inter     Sommer
# 1     133  P    Skorupski      Bologna  Skorupski
# 2    5876  P  Di Gregorio        Monza   Gregorio
# 3     572  P        Meret       Napoli      Meret
# 4    2814  P     Provedel        Lazio   Provedel
# ..    ... ..          ...          ...        ...     ...
# 537  6160  A      Vivaldo      Udinese    Vivaldo
# 538  6242  A      Bidaoui    Frosinone    Bidaoui
# 539  6418  A      Burnete        Lecce    Burnete
# 540  6419  A    Corfitzen        Lecce  Corfitzen
# 541  6427  A      Stewart  Salernitana    Stewart
#
# [542 rows x 6 columns]

# %%
fc_players['fb_ID'] = fc_players['id']

for i in range(fc_players.shape[0]):
    fc_players.loc[i, 'fb_ID']  = -1
    
    for j in range(players.shape[0]):
        if(fc_players['team'][i].lower() in players['team'][j].lower()):
            if(fc_players['surname'][i].lower() == players['surname'][j].lower()):              
                # if(fc_players['initial'][i] == '' or fc_players['initial'][i].lower() == players['initial'][j].lower()):
                if((fc_players['r'][i] == 'P') == (j >= keepers_ID)): # check wether they're a goalkeeper for both FBREF and Fantacalcio
                    fc_players.loc[i, 'fb_ID'] = j
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 10
#       7 if(fc_players['team'][i].lower() in players['team'][j].lower()):
#       8     if(fc_players['surname'][i].lower() == players['surname'][j].lower()):
#       9         # if(fc_players['initial'][i] == '' or fc_players['initial'][i].lower() == players['initial'][j].lower()):
# ---> 10         if((fc_players['r'][i] == 'P') == (j >= keepers_ID)): # check wether they're a goalkeeper for both FBREF and Fantacalcio
#      11             fc_players.loc[i, 'fb_ID'] = j
#
# NameError: name 'keepers_ID' is not defined

# %%
for i in range(fc_players.shape[0]):
    if(fc_players['fb_ID'][i] == -1):
        print(fc_players['name'][i])
# Out:
# Lamanna
# Berisha
# Padelli
# Pinsoglio
# Ravaglia F.
# Brancolini
# Bleve
# Berardi A.
# Gemello
# Boer
# Adamonis
# Marfella
# Piana
# Bagnolini
# Sorrentino A.
# Ciezkowski
# Saro
# Vasquez D.
# Aiwu
# Paletta
# Fares
# Amey
# Guarino
# Machin
# Akpa Akpro
# Galdames
# Darboe
# Urbanski
# Trimboli
# Samek
# Degli Innocenti
# Faticanti
# Oddei
# Kaio Jorge
# Vivaldo

# %%
fc_players
# Out:
#        id  r                 name       team    surname initial  fb_ID
# 0     572  P                Meret     Napoli      Meret            620
# 1    2814  P             Provedel      Lazio   Provedel            632
# 2    4964  P              Vicario     Empoli    Vicario            649
# 3     453  P             Szczesny   Juventus   Szczesny            644
# 4    2134  P              Falcone      Lecce    Falcone            612
# ..    ... ..                  ...        ...        ...     ...    ...
# 538  5512  A              De Luca  Sampdoria       Luca            151
# 539  5837  A  Voelkerling Persson      Lecce    Persson            565
# 540  6113  A            Montevago  Sampdoria  Montevago            365
# 541  6143  A              Krollis     Spezia    Krollis            288
# 542  6160  A              Vivaldo    Udinese    Vivaldo             -1
#
# [543 rows x 7 columns]

# %%
#Data for Outfield players
columns_to_copy = outfield_players.columns[4:]

fc_players[columns_to_copy] = 0

for i in range(fc_players.shape[0]):
    if(fc_players['fb_ID'][i] != -1 and fc_players['r'][i] != 'P'):
         for j in range(columns_to_copy.shape[0]):
            #fc_players[columns_to_copy[j]][i] = outfield_players[columns_to_copy[j]][fc_players['fb_ID'][i]]
            fc_players.loc[i, columns_to_copy[j]] = outfield_players.loc[fc_players['fb_ID'][i], columns_to_copy[j]]
# Out:
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_3484\2261782218.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy] = 0
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_3484\2261782218.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy] = 0
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_3484\2261782218.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy] = 0
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_3484\2261782218.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy] = 0
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_3484\2261782218.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy] = 0
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_3484\2261782218.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy] = 0
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_3484\2261782218.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy] = 0
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_3484\2261782218.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy] = 0
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_3484\2261782218.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy] = 0
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_3484\2261782218.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy] = 0
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_3484\2261782218.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy] = 0
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_3484\2261782218.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy] = 0
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_3484\2261782218.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy] = 0
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_3484\2261782218.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy] = 0
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_3484\2261782218.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy] = 0
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_3484\2261782218.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy] = 0
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_3484\2261782218.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fc_players[columns_to_copy[j]][i] = outfield_players[columns_to_copy[j]][fc_players['fb_ID'][i]]

# %%
keeper_players.columns[4:]
# Out:
# Index(['age', 'birth_year', 'gk_games', 'gk_games_starts', 'gk_minutes',
#        'gk_goals_against', 'gk_goals_against_per90',
#        'gk_shots_on_target_against', 'gk_saves', 'gk_save_pct', 'gk_wins',
#        'gk_ties', 'gk_losses', 'gk_clean_sheets', 'gk_clean_sheets_pct',
#        'gk_pens_att', 'gk_pens_allowed', 'gk_pens_saved', 'gk_pens_missed',
#        'minutes_90s', 'gk_free_kick_goals_against',
#        'gk_corner_kick_goals_against', 'gk_own_goals_against', 'gk_psxg',
#        'gk_psnpxg_per_shot_on_target_against', 'gk_psxg_net',
#        'gk_psxg_net_per90', 'gk_passes_completed_launched',
#        'gk_passes_launched', 'gk_passes_pct_launched', 'gk_passes',
#        'gk_passes_throws', 'gk_pct_passes_launched', 'gk_passes_length_avg',
#        'gk_goal_kicks', 'gk_pct_goal_kicks_launched',
#        'gk_goal_kick_length_avg', 'gk_crosses', 'gk_crosses_stopped',
#        'gk_crosses_stopped_pct', 'gk_def_actions_outside_pen_area',
#        'gk_def_actions_outside_pen_area_per90', 'gk_avg_distance_def_actions'],
#       dtype='object')

# %%
#Data for Keepers
columns_to_copy = keeper_players.columns[4:]

fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year

delta_k = outfield_players.shape[0]

for i in range(fc_players.shape[0]):
    if(fc_players['fb_ID'][i] != -1 and fc_players['r'][i] == 'P'):
        if(fc_players['fb_ID'][i] - delta_k >= 0):
            for j in range(columns_to_copy.shape[0]):          
                #fc_players[columns_to_copy[j]][i] = keeper_players[columns_to_copy[j]][fc_players['fb_ID'][i] - delta_k]
                fc_players.loc[i, columns_to_copy[j]] = keeper_players.loc[fc_players['fb_ID'][i] - delta_k, columns_to_copy[j]]
# Out:
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_3484\3175819694.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_3484\3175819694.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_3484\3175819694.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_3484\3175819694.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_3484\3175819694.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_3484\3175819694.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_3484\3175819694.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_3484\3175819694.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_3484\3175819694.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_3484\3175819694.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_3484\3175819694.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_3484\3175819694.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_3484\3175819694.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_3484\3175819694.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_3484\3175819694.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_3484\3175819694.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_3484\3175819694.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_3484\3175819694.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_3484\3175819694.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_3484\3175819694.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_3484\3175819694.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_3484\3175819694.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_3484\3175819694.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_3484\3175819694.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_3484\3175819694.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_3484\3175819694.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_3484\3175819694.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_3484\3175819694.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_3484\3175819694.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_3484\3175819694.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_3484\3175819694.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_3484\3175819694.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_3484\3175819694.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_3484\3175819694.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_3484\3175819694.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_3484\3175819694.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_3484\3175819694.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_3484\3175819694.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_3484\3175819694.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_3484\3175819694.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fc_players[columns_to_copy[2:]] = 0 # add columns but do not override age and birth_year
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_3484\3175819694.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fc_players[columns_to_copy[j]][i] = keeper_players[columns_to_copy[j]][fc_players['fb_ID'][i] - delta_k]

# %%
keeper_players
# Out:
#                     player nationality position           team  age  \
# 0              Emil Audero      it ITA       GK      Sampdoria   25
# 1          Francesco Bardi      it ITA       GK        Bologna   30
# 2        Marco Carnesecchi      it ITA       GK      Cremonese   22
# 3       Michele Cerofolini      it ITA       GK     Fiorentina   23
# 4          Andrea Consigli      it ITA       GK       Sassuolo   35
# 5              Alex Cordaz      it ITA       GK          Inter   39
# 6           Alessio Cragno      it ITA       GK          Monza   28
# 7      Michele Di Gregorio      it ITA       GK          Monza   25
# 8     Bartłomiej Drągowski      pl POL       GK         Spezia   24
# 9        Wladimiro Falcone      it ITA       GK          Lecce   27
# 10       Vincenzo Fiorillo      it ITA       GK    Salernitana   32
# 11       Pierluigi Gollini      it ITA       GK         Napoli   27
# 12       Pierluigi Gollini      it ITA       GK     Fiorentina   27
# 13        Samir Handanović      si SVN       GK          Inter   38
# 14            Mike Maignan      fr FRA       GK          Milan   27
# 15      Federico Marchetti      it ITA       GK         Spezia   39
# 16          Luís Maximiano      pt POR       GK          Lazio   23
# 17              Alex Meret      it ITA       GK         Napoli   25
# 18  Vanja Milinković-Savić      rs SRB       GK         Torino   25
# 19         Antonio Mirante      it ITA       GK          Milan   39
# 20         Lorenzo Montipò      it ITA       GK  Hellas Verona   26
# 21              Juan Musso      ar ARG       GK       Atalanta   28
# 22         Guillermo Ochoa      mx MEX       GK    Salernitana   37
# 23             André Onana      cm CMR       GK          Inter   26
# 24            Rui Patrício      pt POR       GK           Roma   34
# 25         Gianluca Pegolo      it ITA       GK       Sassuolo   41
# 26          Simone Perilli      it ITA       GK  Hellas Verona   27
# 27            Mattia Perin      it ITA       GK       Juventus   29
# 28         Samuele Perisan      it ITA       GK         Empoli   24
# 29           Ivan Provedel      it ITA       GK          Lazio   28
# 30              Ionuț Radu      ro ROU       GK      Cremonese   25
# 31         Nicola Ravaglia      it ITA       GK      Sampdoria   33
# 32         Francesco Rossi      it ITA       GK       Atalanta   31
# 33        Alessandro Russo      it ITA       GK       Sassuolo   21
# 34         Mouhamadou Sarr      sn SEN       GK      Cremonese   25
# 35              Luigi Sepe      it ITA       GK    Salernitana   31
# 36         Marco Silvestri      it ITA       GK        Udinese   31
# 37        Salvatore Sirigu      it ITA       GK     Fiorentina   35
# 38        Łukasz Skorupski      pl POL       GK        Bologna   31
# 39        Marco Sportiello      it ITA       GK       Atalanta   30
# 40             Mile Svilar      rs SRB       GK           Roma   22
# 41       Wojciech Szczęsny      pl POL       GK       Juventus   32
# 42      Ciprian Tătărușanu      ro ROU       GK          Milan   36
# 43      Pietro Terracciano      it ITA       GK     Fiorentina   32
# 44             Martin Turk      si SVN       GK      Sampdoria   18
# 45            Samir Ujkani      xk KVX       GK         Empoli   34
# 46       Guglielmo Vicario      it ITA       GK         Empoli   25
# 47             Jeroen Zoet      nl NED       GK         Spezia   31
# 48             Petar Zovko      ba BIH       GK         Spezia   20
#
#     birth_year  gk_games  gk_games_starts  gk_minutes  gk_goals_against  ...  \
# 0         1997      25.0             25.0      2250.0              39.0  ...
# 1         1992       1.0              1.0        90.0               0.0  ...
# 2         2000      27.0             27.0      2430.0              47.0  ...
# 3         1999       5.0              5.0       450.0               3.0  ...
# 4         1987      35.0             35.0      3150.0              55.0  ...
# 5         1983       1.0              0.0        26.0               0.0  ...
# 6         1994       1.0              1.0        90.0               3.0  ...
# 7         1997      37.0             37.0      3330.0              49.0  ...
# 8         1997      34.0             34.0      2946.0              54.0  ...
# 9         1995      38.0             38.0      3420.0              46.0  ...
# 10        1990       1.0              1.0        90.0               2.0  ...
# 11        1995       4.0              4.0       360.0               4.0  ...
# 12        1995       3.0              3.0       270.0               2.0  ...
# 13        1984      14.0             14.0      1234.0              18.0  ...
# 14        1995      22.0             22.0      1978.0              21.0  ...
# 15        1983       1.0              0.0        66.0               2.0  ...
# 16        1999       1.0              1.0         5.0               0.0  ...
# 17        1997      34.0             34.0      3060.0              24.0  ...
# 18        1997      38.0             38.0      3420.0              41.0  ...
# 19        1983       1.0              0.0         2.0               0.0  ...
# 20        1996      37.0             37.0      3330.0              59.0  ...
# 21        1994      24.0             24.0      2077.0              27.0  ...
# 22        1985      20.0             20.0      1800.0              33.0  ...
# 23        1996      24.0             24.0      2160.0              24.0  ...
# 24        1988      35.0             35.0      3150.0              35.0  ...
# 25        1981       2.0              2.0       180.0               3.0  ...
# 26        1995       1.0              1.0        90.0               0.0  ...
# 27        1992      11.0             10.0       948.0               7.0  ...
# 28        1997       7.0              7.0       630.0               9.0  ...
# 29        1994      38.0             37.0      3413.0              30.0  ...
# 30        1997       9.0              9.0       810.0              19.0  ...
# 31        1988       9.0              9.0       810.0              23.0  ...
# 32        1991       1.0              0.0         4.0               0.0  ...
# 33        2001       1.0              1.0        90.0               3.0  ...
# 34        1997       2.0              2.0       180.0               3.0  ...
# 35        1991      17.0             17.0      1530.0              27.0  ...
# 36        1991      38.0             38.0      3420.0              48.0  ...
# 37        1987       1.0              1.0        90.0               0.0  ...
# 38        1991      37.0             37.0      3330.0              49.0  ...
# 39        1992      15.0             14.0      1339.0              21.0  ...
# 40        1999       3.0              3.0       270.0               3.0  ...
# 41        1990      28.0             28.0      2472.0              26.0  ...
# 42        1986      16.0             16.0      1440.0              22.0  ...
# 43        1990      29.0             29.0      2610.0              38.0  ...
# 44        2003       4.0              4.0       360.0               9.0  ...
# 45        1988       1.0              0.0         7.0               1.0  ...
# 46        1996      31.0             31.0      2783.0              39.0  ...
# 47        1991       5.0              4.0       334.0               4.0  ...
# 48        2002       1.0              0.0        74.0               2.0  ...
#
#     gk_passes_length_avg  gk_goal_kicks  gk_pct_goal_kicks_launched  \
# 0                   39.1          200.0                        57.0
# 1                   35.6            9.0                        44.4
# 2                   41.4          203.0                        66.0
# 3                   33.3           28.0                        42.9
# 4                   33.3          285.0                        31.2
# 5                   33.5            5.0                        60.0
# 6                   22.6            6.0                        16.7
# 7                   32.2          247.0                        37.2
# 8                   34.6          196.0                        58.7
# 9                   42.1          282.0                        79.1
# 10                  37.9            5.0                        80.0
# 11                  29.6           31.0                        32.3
# 12                  32.4           11.0                        63.6
# 13                  24.7           71.0                        11.3
# 14                  29.8           85.0                        32.9
# 15                  24.3            8.0                        37.5
# 16                   0.0            0.0                         0.0
# 17                  26.1          198.0                        20.2
# 18                  39.7          286.0                        91.3
# 19                  27.0            1.0                         0.0
# 20                  44.3          284.0                        72.5
# 21                  32.1          157.0                        62.4
# 22                  40.9          200.0                        66.0
# 23                  29.6          152.0                        30.9
# 24                  33.6          240.0                        35.8
# 25                  29.7           16.0                        31.3
# 26                  57.3           13.0                       100.0
# 27                  30.8           63.0                        39.7
# 28                  32.7           75.0                        34.7
# 29                  32.2          198.0                        33.3
# 30                  37.3           67.0                        50.7
# 31                  35.6           99.0                        49.5
# 32                  17.3            1.0                       100.0
# 33                  30.7            8.0                         0.0
# 34                  35.7           12.0                        75.0
# 35                  35.9          154.0                        48.7
# 36                  32.0          302.0                        33.8
# 37                  37.7            8.0                        50.0
# 38                  31.7          278.0                        33.5
# 39                  28.8          116.0                        66.4
# 40                  41.4           16.0                        81.3
# 41                  33.5          153.0                        43.1
# 42                  32.9           83.0                        51.8
# 43                  33.2          198.0                        45.5
# 44                  35.1           43.0                        86.0
# 45                  18.5            1.0                         0.0
# 46                  33.8          170.0                        50.0
# 47                  39.0           23.0                        78.3
# 48                  35.1           13.0                        76.9
#
#     gk_goal_kick_length_avg  gk_crosses  gk_crosses_stopped  \
# 0
k_def_actions_outside_pen_area_per90  gk_avg_distance_def_actions
# 0                                    0.92                         13.9
# 1                                    0.00                          0.0
# 2                                    1.07                         14.1
# 3                                    0.60                         13.8
# 4                                    0.80                         14.2
# 5                                    0.00                          0.0
# 6                                    2.00                         25.7
# 7                                    0.86                         13.4
# 8                                    0.98                         14.1
# 9                                    1.11                         14.1
# 10                                   0.00                          6.0
# 11                                   1.00                         18.8
# 12                                   0.00                          9.3
# 13                                   0.73                         15.4
# 14                                   1.46                         17.8
# 15                                   1.36                         22.0
# 16                                   0.00                         19.0
# 17                                   1.15                         17.0
# 18                                   1.84                         16.2
# 19                                   0.00                          0.0
# 20                                   1.49                         15.3
# 21                                   1.04                         15.6
# 22                                   0.50                         12.3
# 23                                   0.42                         12.5
# 24                                   0.71                         13.8
# 25                                   0.00                          9.0
# 26                                   1.00                         12.0
# 27                                   1.04                         15.7
# 28                                   0.57                         11.6
# 29                                   1.45                         16.5
# 30                                   1.00                         14.5
# 31                                   0.11                         10.5
# 32                                   0.00                          0.0
# 33                                   0.00                         10.0
# 34                                   0.50                          8.6
# 35                                   0.76                         14.2
# 36                                   0.55                         12.2
# 37                                   2.00                         26.3
# 38                                   0.65                         12.9
# 39                                   1.21                         15.0
# 40                                   1.33                         12.1
# 41                                   0.76                         14.7
# 42                                   0.81                         14.4
# 43                                   1.90                         18.4
# 44                                   0.50                         12.3
# 45                                   0.00                          0.0
# 46                                   0.71                         11.5
# 47                                   1.61                         14.7
# 48                                   2.47                         17.0
#
# [49 rows x 47 columns]

# %%
fc_players
# Out:
#        id  r                 name       team    surname initial  fb_ID  age  \
# 0     572  P                Meret     Napoli      Meret            620   25
# 1    2814  P             Provedel      Lazio   Provedel            632   28
# 2    4964  P              Vicario     Empoli    Vicario            649   25
# 3     453  P             Szczesny   Juventus   Szczesny            644   32
# 4    2134  P              Falcone      Lecce    Falcone            612   27
# ..    ... ..                  ...        ...        ...     ...    ...  ...
# 538  5512  A              De Luca  Sampdoria       Luca            151   24
# 539  5837  A  Voelkerling Persson      Lecce    Persson            565   19
# 540  6113  A            Montevago  Sampdoria  Montevago            365   19
# 541  6143  A              Krollis     Spezia    Krollis            288   20
# 542  6160  A              Vivaldo    Udinese    Vivaldo             -1    0
#
#      birth_year  games  ...  gk_passes_length_avg  gk_goal_kicks  \
# 0          1997      0  ...                  26.1            198
# 1          1994      0  ...                  32.2            198
# 2          1996      0  ...                  33.8            170
# 3          1990      0  ...                  33.5            153
# 4          1995      0  ...                  42.1            282
# ..          ...    ...  ...                   ...            ...
# 538        1998      2  ...                   0.0              0
# 539        2003      9  ...                   0.0              0
# 540        2003      6  ...                   0.0              0
# 541        2001      4  ...                   0.0              0
# 542           0      0  ...                   0.0              0
#
#      gk_pct_goal_kicks_launched  gk_goal_kick_length_avg  gk_crosses  \
# 0                          20.2                     26.9         335
# 1                          33.3                     33.2         493
# 2                          50.0                     42.9         606
# 3                          43.1                     38.3         389
# 4                          79.1                     53.5         534
# ..                          ...                      ...         ...
# 538                         0.0                      0.0           0
# 539                         0.0                      0.0           0
# 540                         0.0                      0.0           0
# 541                         0.0                      0.0           0
# 542                         0.0                      0.0           0
#
#      gk_crosses_stopped  gk_crosses_stopped_pct  \
# 0                    11                     3.3
# 1                    21                     4.3
# 2                    34                     5.6
# 3                    11                     2.8
# 4                    23                     4.3
# ..                  ...                     ...
# 538                   0                     0.0
# 539                   0                     0.0
# 540                   0                     0.0
# 541                   0                     0.0
# 542                   0                     0.0
#
#      gk_def_actions_outside_pen_area  gk_def_actions_outside_pen_area_per90  \
# 0                                 39                                   1.15
# 1                                 55                                   1.45
# 2                                 22                                   0.71
# 3                                 21                                   0.76
# 4                                 42                                   1.11
# ..                               ...                                    ...
# 538                                0                                   0.00
# 539                                0                                   0.00
# 540                                0                                   0.00
# 541                                0                                   0.00
# 542                                0                                   0.00
#
#      gk_avg_distance_def_actions
# 0                           17.0
# 1                           16.5
# 2                           11.5
# 3                           14.7
# 4                           14.1
# ..                           ...
# 538                          0.0
# 539                          0.0
# 540                          0.0
# 541                          0.0
# 542                          0.0
#
# [543 rows x 158 columns]

# %%
import numpy as np

votes = pd.read_excel('mid_outputs/season' + season + '/players_votes.xlsx', index_col = 0)

mean_def = 6
std_def = 0.58

mean_def_P = 6.22
std_def_P = 0.43


min_votes = 6


perf_df = pd.DataFrame(columns = ['vote_avg', 'vote_std'])

for i in range(fc_players.shape[0]):
    v = np.array([])
    for j in range(votes.shape[0]):
        if(fc_players['name'][i] == votes['player'][j]):
            v = np.append(v, votes['vote'][j])
    
    if(fc_players['r'][i] == 'P'):
        mean_def_i = mean_def_P
        std_def_i = std_def_P
        
    if(v.shape[0] < min_votes):
         for k in range(min_votes - v.shape[0]):
            v = np.append( v, np.random.normal(mean_def_i, std_def_i) )
    
    row_df = pd.DataFrame(data = [[np.mean(v), np.std(v)]], columns = perf_df.columns)
    perf_df = pd.concat([perf_df, row_df], ignore_index = True)
    
perf_df
# Out:
#      vote_avg  vote_std
# 0    6.176471  0.400043
# 1    6.263158  0.409378
# 2    6.403226  0.447562
# 3    6.107143  0.309295
# 4    6.250000  0.547122
# ..        ...       ...
# 538  5.871240  0.394770
# 539  6.132748  0.474211
# 540  5.722482  0.229188
# 541  6.357731  0.405367
# 542  6.006617  0.274006
#
# [543 rows x 2 columns]

# %%
fc_players = pd.concat([fc_players, perf_df], axis = 1)

fc_players
# Out:
#        id  r                 name       team    surname initial  fb_ID  age  \
# 0     572  P                Meret     Napoli      Meret            620   25
# 1    2814  P             Provedel      Lazio   Provedel            632   28
# 2    4964  P              Vicario     Empoli    Vicario            649   25
# 3     453  P             Szczesny   Juventus   Szczesny            644   32
# 4    2134  P              Falcone      Lecce    Falcone            612   27
# ..    ... ..                  ...        ...        ...     ...    ...  ...
# 538  5512  A              De Luca  Sampdoria       Luca            151   24
# 539  5837  A  Voelkerling Persson      Lecce    Persson            565   19
# 540  6113  A            Montevago  Sampdoria  Montevago            365   19
# 541  6143  A              Krollis     Spezia    Krollis            288   20
# 542  6160  A              Vivaldo    Udinese    Vivaldo             -1    0
#
#      birth_year  games  ...  gk_pct_goal_kicks_launched  \
# 0          1997      0  ...                        20.2
# 1          1994      0  ...                        33.3
# 2          1996      0  ...                        50.0
# 3          1990      0  ...                        43.1
# 4          1995      0  ...                        79.1
# ..          ...    ...  ...                         ...
# 538        1998      2  ...                         0.0
# 539        2003      9  ...                         0.0
# 540        2003      6  ...                         0.0
# 541        2001      4  ...                         0.0
# 542           0      0  ...                         0.0
#
#      gk_goal_kick_length_avg  gk_crosses  gk_crosses_stopped  \
# 0                       26.9         335                  11
# 1                       33.2         493                  21
# 2                       42.9         606                  34
# 3                       38.3         389                  11
# 4                       53.5         534                  23
# ..                       ...         ...                 ...
# 538                      0.0           0                   0
# 539                      0.0           0                   0
# 540                      0.0           0                   0
# 541                      0.0           0                   0
# 542                      0.0           0                   0
#
#      gk_crosses_stopped_pct  gk_def_actions_outside_pen_area  \
# 0                       3.3                               39
# 1                       4.3                               55
# 2                       5.6                               22
# 3                       2.8                               21
# 4                       4.3                               42
# ..                      ...                              ...
# 538                     0.0                                0
# 539                     0.0                                0
# 540                     0.0                                0
# 541                     0.0                                0
# 542                     0.0                                0
#
#      gk_def_actions_outside_pen_area_per90  gk_avg_distance_def_actions  \
# 0                                     1.15                         17.0
# 1                                     1.45                         16.5
# 2                                     0.71                         11.5
# 3                                     0.76                         14.7
# 4                                     1.11                         14.1
# ..                                     ...                          ...
# 538                                   0.00                          0.0
# 539                                   0.00                          0.0
# 540                                   0.00                          0.0
# 541                                   0.00                          0.0
# 542                                   0.00                          0.0
#
#      vote_avg  vote_std
# 0    6.176471  0.400043
# 1    6.263158  0.409378
# 2    6.403226  0.447562
# 3    6.107143  0.309295
# 4    6.250000  0.547122
# ..        ...       ...
# 538  5.871240  0.394770
# 539  6.132748  0.474211
# 540  5.722482  0.229188
# 541  6.357731  0.405367
# 542  6.006617  0.274006
#
# [543 rows x 160 columns]

# %%
min_gk_games = 6

fc_players_newgk = fc_players.copy()

columns_to_avg = fc_players.columns[123:] # from gk_games to end

for i in range(fc_players.shape[0]):
    if(fc_players['r'][i] == 'P'):
        if(fc_players['gk_games'][i] < min_gk_games):
            for j in range(fc_players.shape[0]):
                if(fc_players['team'][i] == fc_players['team'][j] and fc_players['gk_games'][j] >= min_gk_games):
                    break
                    
            weight = 1 - (min_gk_games - fc_players['gk_games'][i]) / min_gk_games
            
            fc_players_newgk.at[i, columns_to_avg] = fc_players.loc[i][columns_to_avg] * weight + (1 - weight) * fc_players.loc[j][columns_to_avg]
            
            print(fc_players['name'][i] + ', ' + str(weight))
# Out:
# Zoet, 0.8333333333333334
# Pegolo, 0.33333333333333337
# Gollini, 0.6666666666666667
# Mirante, 0.16666666666666663
# Sarr M., 0.33333333333333337
# Lamanna, 0.0
# Ujkani, 0.16666666666666663
# Berisha, 0.0
# Marchetti, 0.16666666666666663
# Perilli, 0.16666666666666663
# Padelli, 0.0
# Bardi, 0.16666666666666663
# Cordaz, 0.16666666666666663
# Pinsoglio, 0.0
# Fiorillo, 0.16666666666666663
# Cragno, 0.16666666666666663
# Sirigu, 0.16666666666666663
# Cerofolini, 0.8333333333333334
# Rossi F., 0.16666666666666663
# Ravaglia F., 0.0
# Brancolini, 0.0
# Bleve, 0.0
# Berardi A., 0.0
# Russo A., 0.16666666666666663
# Gemello, 0.0
# Boer, 0.0
# Adamonis, 0.0
# Marfella, 0.0
# Zovko, 0.16666666666666663
# Piana, 0.0
# Bagnolini, 0.0
# Luis Maximiano, 0.16666666666666663
# Svilar, 0.5
# Sorrentino A., 0.0
# Ciezkowski, 0.0
# Saro, 0.0
# Vasquez D., 0.0
# Turk, 0.6666666666666667

# %%
fc_players = fc_players_newgk

fc_players
# Out:
#        id  r                 name       team    surname initial  fb_ID  age  \
# 0     572  P                Meret     Napoli      Meret            620   25
# 1    2814  P             Provedel      Lazio   Provedel            632   28
# 2    4964  P              Vicario     Empoli    Vicario            649   25
# 3     453  P             Szczesny   Juventus   Szczesny            644   32
# 4    2134  P              Falcone      Lecce    Falcone            612   27
# ..    ... ..                  ...        ...        ...     ...    ...  ...
# 538  5512  A              De Luca  Sampdoria       Luca            151   24
# 539  5837  A  Voelkerling Persson      Lecce    Persson            565   19
# 540  6113  A            Montevago  Sampdoria  Montevago            365   19
# 541  6143  A              Krollis     Spezia    Krollis            288   20
# 542  6160  A              Vivaldo    Udinese    Vivaldo             -1    0
#
#      birth_year  games  ...  gk_pct_goal_kicks_launched  \
# 0          1997      0  ...                        20.2
# 1          1994      0  ...                        33.3
# 2          1996      0  ...                        50.0
# 3          1990      0  ...                        43.1
# 4          1995      0  ...                        79.1
# ..          ...    ...  ...                         ...
# 538        1998      2  ...                         0.0
# 539        2003      9  ...                         0.0
# 540        2003      6  ...                         0.0
# 541        2001      4  ...                         0.0
# 542           0      0  ...                         0.0
#
#      gk_goal_kick_length_avg  gk_crosses  gk_crosses_stopped  \
# 0                       26.9       335.0                11.0
# 1                       33.2       493.0                21.0
# 2                       42.9       606.0                34.0
# 3                       38.3       389.0                11.0
# 4                       53.5       534.0                23.0
# ..                       ...         ...                 ...
# 538                      0.0         0.0                 0.0
# 539                      0.0         0.0                 0.0
# 540                      0.0         0.0                 0.0
# 541                      0.0         0.0                 0.0
# 542                      0.0         0.0                 0.0
#
#      gk_crosses_stopped_pct  gk_def_actions_outside_pen_area  \
# 0                       3.3                             39.0
# 1                       4.3                             55.0
# 2                       5.6                             22.0
# 3                       2.8                             21.0
# 4                       4.3                             42.0
# ..                      ...                              ...
# 538                     0.0                              0.0
# 539                     0.0                              0.0
# 540                     0.0                              0.0
# 541                     0.0                              0.0
# 542                     0.0                              0.0
#
#      gk_def_actions_outside_pen_area_per90  gk_avg_distance_def_actions  \
# 0                                     1.15                         17.0
# 1                                     1.45                         16.5
# 2                                     0.71                         11.5
# 3                                     0.76                         14.7
# 4                                     1.11                         14.1
# ..                                     ...                          ...
# 538                                   0.00                          0.0
# 539                                   0.00                          0.0
# 540                                   0.00                          0.0
# 541                                   0.00                          0.0
# 542                                   0.00                          0.0
#
#      vote_avg  vote_std
# 0    6.176471  0.400043
# 1    6.263158  0.409378
# 2    6.403226  0.447562
# 3    6.107143  0.309295
# 4    6.250000  0.547122
# ..        ...       ...
# 538  5.871240  0.394770
# 539  6.132748  0.474211
# 540  5.722482  0.229188
# 541  6.357731  0.405367
# 542  6.006617  0.274006
#
# [543 rows x 160 columns]

# %%
fc_players.to_excel('mid_outputs/season' + season + '/players_stats.xlsx')
