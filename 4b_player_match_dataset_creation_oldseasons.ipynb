# %% [markdown]
# player_match_dataset_creation code for past seasons
#
# Select the season in season variable, and repeat the code if needed

# %%
season = '2324'

# %%
import pandas as pd

rcsv = pd.read_csv('fbref_data/season' + season + '/teams.csv')   
team = pd.DataFrame(rcsv)

rcsv = pd.read_csv('fbref_data/season' + season + '/teams_vs.csv')   
vs_team = pd.DataFrame(rcsv)

for i in range(1, team.shape[1]):
    team = team.rename(columns = {team.columns[i] : 'team_' + team.columns[i]})
    
for i in range(1, vs_team.shape[1]):
    vs_team = vs_team.rename(columns = {vs_team.columns[i] : 'vs_team_' + vs_team.columns[i]})
    
vs_team.pop('team')

team_data = pd.concat([team, vs_team], axis = 1)

team_data['team_idx'] = team_data['team']
for i in range(team_data.shape[0]):
    team_data.loc[i, 'team_idx'] = team_data.loc[i, 'team_idx'].split(' ')[-1]

team_data = team_data.set_index('team_idx')

team_data
# Out:
#                       team  team_players_used  team_possession  team_games  \
# team_idx
# Atalanta          Atalanta               29.0             51.1        38.0
# Bologna            Bologna               28.0             58.1        38.0
# Cagliari          Cagliari               29.0             42.1        38.0
# Empoli              Empoli               34.0             44.0        38.0
# Fiorentina      Fiorentina               30.0             57.3        38.0
# Frosinone        Frosinone               34.0             49.7        38.0
# Genoa                Genoa               34.0             44.1        38.0
# Verona       Hellas Verona               36.0             44.4        38.0
# Inter                Inter               27.0             57.1        38.0
# Juventus          Juventus               31.0             48.5        38.0
# Lazio                Lazio               22.0             53.3        38.0
# Lecce                Lecce               26.0             44.9        38.0
# Milan                Milan               35.0             56.9        38.0
# Monza                Monza               31.0             53.5        38.0
# Napoli              Napoli               29.0             60.9        38.0
# Roma                  Roma               30.0             54.9        38.0
# Salernitana    Salernitana               39.0             44.5        38.0
# Sassuolo          Sassuolo               30.0             43.8        38.0
# Torino              Torino               30.0             51.6        38.0
# Udinese            Udinese               32.0             39.3        38.0
#
#              team_games_starts  team_minutes  team_goals  team_assists  \
# team_idx
# Atalanta                 418.0        3420.0        72.0          57.0
# Bologna                  418.0        3420.0        52.0          32.0
# Cagliari                 418.0        3420.0        41.0          30.0
# Empoli                   418.0        3420.0        26.0          19.0
# Fiorentina               418.0        3420.0        60.0          41.0
# Frosinone                418.0        3420.0        44.0          29.0
# Genoa                    418.0        3420.0        43.0          27.0
# Verona                   418.0        3420.0        38.0          29.0
# Inter                    418.0        3420.0        87.0          60.0
# Juventus                 418.0        3420.0        52.0          37.0
# Lazio                    418.0        3420.0        46.0          30.0
# Lecce                    418.0        3420.0        30.0          23.0
# Milan                    418.0        3420.0        76.0          56.0
# Monza                    418.0        3420.0        38.0          29.0
# Napoli                   418.0        3420.0        54.0          36.0
# Roma                     418.0        3420.0        64.0          44.0
# Salernitana              418.0        3420.0        32.0          25.0
# Sassuolo                 418.0        3420.0        42.0          28.0
# Torino                   418.0        3420.0        35.0          29.0
# Udinese                  418.0        3420.0        36.0          23.0
#
#              team_pens_made  team_pens_att  ...  vs_team_fouls  \
# team_idx                                    ...
# Atalanta                5.0            5.0  ...          395.0
# Bologna                 4.0            5.0  ...          503.0
# Cagliari                4.0            6.0  ...          441.0
# Empoli                  5.0            5.0  ...          530.0
# Fiorentina              4.0            8.0  ...          478.0
# Frosinone               8.0           10.0  ...          482.0
# Genoa                   5.0            6.0  ...          449.0
# Verona                  3.0            7.0  ...          478.0
# Inter                  13.0           14.0  ...          434.0
# Juventus                3.0            5.0  ...          401.0
# Lazio                   4.0            4.0  ...          459.0
# Lecce                   3.0            5.0  ...          508.0
# Milan                   6.0            8.0  ...          430.0
# Monza                   4.0            5.0  ...          431.0
# Napoli                  6.0           10.0  ...          478.0
# Roma                   11.0           12.0  ...          458.0
# Salernitana             2.0            2.0  ...          498.0
# Sassuolo                7.0            8.0  ...          424.0
# Torino                  2.0            2.0  ...          435.0
# Udinese                 3.0            4.0  ...          445.0
#
#              vs_team_fouled  vs_team_offsides  vs_team_pens_won  \
# team_idx
# Atalanta              454.0              58.0               7.0
# Bologna               443.0              49.0               6.0
# Cagliari              434.0              91.0               1.0
# Empoli                487.0              49.0               6.0
# Fiorentina            422.0              89.0               7.0
# Frosinone             352.0              71.0               5.0
# Genoa                 419.0              68.0               4.0
# Verona                518.0              84.0               1.0
# Inter                 378.0              41.0               4.0
# Juventus              454.0              25.0               2.0
# Lazio                 453.0              39.0               1.0
# Lecce                 468.0              37.0               3.0
# Milan                 403.0              49.0               7.0
# Monza                 434.0              46.0               7.0
# Napoli                350.0              75.0               3.0
# Roma                  436.0              44.0               3.0
# Salernitana           422.0              79.0               6.0
# Sassuolo              363.0             112.0               7.0
# Torino                445.0              38.0               6.0
# Udinese               469.0              51.0               6.0
#
#              vs_team_pens_conceded  vs_team_own_goals  \
# team_idx
# Atalanta                       5.0                0.0
# Bologna                        5.0                2.0
# Cagliari                       6.0                1.0
# Empoli                         5.0                3.0
# Fiorentina                     8.0                1.0
# Frosinone                     10.0                0.0
# Genoa                          6.0                2.0
# Verona                         7.0                0.0
# Inter                         14.0                2.0
# Juventus                       5.0                2.0
# Lazio                          4.0                3.0
# Lecce                          5.0                2.0
# Milan                          8.0                0.0
# Monza                          5.0                1.0
# Napoli                        10.0                1.0
# Roma                          12.0                1.0
# Salernitana                    2.0                0.0
# Sassuolo                       8.0                1.0
# Torino                         2.0                1.0
# Udinese                        4.0                1.0
#
#              vs_team_ball_recoveries  vs_team_aerials_won  \
# team_idx
# Atalanta                      1937.0                491.0
# Bologna                       1744.0                413.0
# Cagliari                      1722.0                613.0
# Empoli                        1687.0                628.0
# Fiorentina                    1623.0                603.0
# Frosinone                     1855.0                602.0
# Genoa                         1713.0                543.0
# Verona                        1812.0                644.0
# Inter                         1432.0                370.0
# Juventus                      1582.0                434.0
# Lazio                         1782.0                453.0
# Lecce                         1791.0                616.0
# Milan                         1614.0                410.0
# Monza                         1610.0                462.0
# Napoli                        1596.0                483.0
# Roma                          1649.0                443.0
# Salernitana                   1785.0                662.0
# Sassuolo                      1794.0                607.0
# Torino                        1649.0                594.0
# Udinese                       1654.0                467.0
#
#              vs_team_aerials_lost  vs_team_aerials_won_pct
# team_idx
# Atalanta                    627.0                     43.9
# Bologna                     416.0                     49.8
# Cagliari                    571.0                     51.8
# Empoli                      509.0                     55.2
# Fiorentina                  626.0                     49.1
# Frosinone                   518.0                     53.8
# Genoa                       610.0                     47.1
# Verona                      750.0                     46.2
# Inter                       535.0                     40.9
# Juventus                    486.0                     47.2
# Lazio                       399.0                     53.2
# Lecce                       548.0                     52.9
# Milan                       432.0                     48.7
# Monza                       442.0                     51.1
# Napoli                      470.0                     50.7
# Roma                        478.0                     48.1
# Salernitana                 520.0                     56.0
# Sassuolo                    452.0                     57.3
# Torino                      588.0                     50.3
# Udinese                     561.0                     45.4
#
# [20 rows x 303 columns]

# %%
team_data.to_excel('mid_outputs/season' + season + '/team_data.xlsx')

# %%
rx = pd.read_excel('mid_outputs/season' + season + '/players_stats.xlsx', index_col = 3)   
players = pd.DataFrame(rx)

players
# Out:
#              Unnamed: 0    id  r         team    surname initial  fb_ID  age  \
# name
# Sommer                0  2428  P        Inter     Sommer     NaN    660   34
# Skorupski             1   133  P      Bologna  Skorupski     NaN    658   32
# Di Gregorio           2  5876  P        Monza   Gregorio     NaN    629   26
# Meret                 3   572  P       Napoli      Meret     NaN    639   26
# Provedel              4  2814  P        Lazio   Provedel     NaN    652   29
# ...                 ...   ... ..          ...        ...     ...    ...  ...
# Vivaldo             537  6160  A      Udinese    Vivaldo     NaN     -1    0
# Bidaoui             538  6242  A    Frosinone    Bidaoui     NaN     -1    0
# Burnete             539  6418  A        Lecce    Burnete     NaN     87   19
# Corfitzen           540  6419  A        Lecce  Corfitzen     NaN    137   18
# Stewart             541  6427  A  Salernitana    Stewart     NaN    539   23
#
#              birth_year  games  ...  gk_pct_goal_kicks_launched  \
# name                            ...
# Sommer             1988      0  ...                        22.9
# Skorupski          1991      0  ...                        42.0
# Di Gregorio        1997      0  ...                        52.5
# Meret              1997      0  ...                        22.6
# Provedel           1994      0  ...                        35.2
# ...                 ...    ...  ...                         ...
# Vivaldo               0      0  ...                         0.0
# Bidaoui               0      0  ...                         0.0
# Burnete            2004      1  ...                         0.0
# Corfitzen          2004      1  ...                         0.0
# Stewart            2000      4  ...                         0.0
#
#              gk_goal_kick_length_avg  gk_crosses  gk_crosses_stopped  \
# name
# Sommer                          27.9         395                  18
# Skorupski                       38.7         432                  12
# Di Gregorio                     44.2         469                  19
# Meret                           29.5         334                   9
# Provedel                        37.0         377                  15
# ...                              ...         ...                 ...
# Vivaldo                          0.0           0                   0
# Bidaoui                          0.0           0                   0
# Burnete                          0.0           0                   0
# Corfitzen                        0.0           0                   0
# Stewart                          0.0           0                   0
#
#              gk_crosses_stopped_pct  gk_def_actions_outside_pen_area  \
# name
# Sommer                          4.6                               14
# Skorupski                       2.8                               15
# Di Gregorio                     4.1                               18
# Meret                           2.7                               29
# Provedel                        4.0                               18
# ...                             ...                              ...
# Vivaldo                         0.0                                0
# Bidaoui                         0.0                                0
# Burnete                         0.0                                0
# Corfitzen                       0.0                                0
# Stewart                         0.0                                0
#
#              gk_def_actions_outside_pen_area_per90  \
# name
# Sommer                                        0.41
# Skorupski                                     0.47
# Di Gregorio                                   0.56
# Meret                                         0.94
# Provedel                                      0.60
# ...                                            ...
# Vivaldo                                       0.00
# Bidaoui                                       0.00
# Burnete                                       0.00
# Corfitzen                                     0.00
# Stewart                                       0.00
#
#              gk_avg_distance_def_actions  vote_avg  vote_std
# name
# Sommer                              12.1  6.117647  0.470588
# Skorupski                           12.2  6.171875  0.461136
# Di Gregorio                         11.5  6.348485  0.583678
# Meret                               15.4  6.064516  0.435185
# Provedel                            13.0  6.233333  0.478423
# ...                                  ...       ...       ...
# Vivaldo                              0.0  6.473478  0.301242
# Bidaoui                              0.0  6.678246  0.541580
# Burnete                              0.0  5.862853  0.258067
# Corfitzen                            0.0  6.076806  0.357053
# Stewart                              0.0  5.938563  0.329044
#
# [542 rows x 160 columns]

# %%
def player_match_data(player, pteam, oppteam):
    if(not(player in players.index)):
        return None
    
    pdata = players.loc[[player]]
    
    pteam_stats = team_data.loc[[pteam]].rename(index = {pteam : player})
    
    oppteam_stats = team_data.loc[[oppteam]].rename(index = {oppteam : player})
    
    oppteam_stats = oppteam_stats.rename(lambda x: 'opp_' + x, axis='columns')
    
    out = pd.concat([pdata, pteam_stats, oppteam_stats], axis = 1)
    
    return(out)

# %%
test = player_match_data('Immobile', 'Lazio', 'Atalanta')
test.to_excel('tmp/playermatchdata.xlsx')

test
# Out:
#           Unnamed: 0   id  r   team   surname initial  fb_ID  age  birth_year  \
# Immobile         450  785  A  Lazio  Immobile     NaN    265   33        1990
#
#           games  ...  opp_vs_team_fouls  opp_vs_team_fouled  \
# Immobile     31  ...              395.0               454.0
#
#           opp_vs_team_offsides  opp_vs_team_pens_won  \
# Immobile                  58.0                   7.0
#
#           opp_vs_team_pens_conceded  opp_vs_team_own_goals  \
# Immobile                        5.0                    0.0
#
#           opp_vs_team_ball_recoveries  opp_vs_team_aerials_won  \
# Immobile                       1937.0                    491.0
#
#           opp_vs_team_aerials_lost  opp_vs_team_aerials_won_pct
# Immobile                     627.0                         43.9
#
# [1 rows x 766 columns]

# %%
pteam = 'Lazio'
pteam_stats = team_data.loc[[pteam]]
pteam_stats.index[0]
# Out:
# 'Lazio'

# %%
rx = pd.read_excel('tmp/playermatchdata_sel.xlsx', index_col = 0, header = None)   

out = list()

for i in range(1, rx.shape[1]):
        if(rx[i][2] == "x"):
            out.append(rx[i][0])
            
out
# Out:
# ['r',
#  'fb_ID',
#  'games',
#  'games_starts',
#  'minutes',
#  'goals',
#  'assists',
#  'cards_yellow',
#  'cards_red',
#  'xg',
#  'npxg',
#  'shots_on_target',
#  'shots_on_target_pct',
#  'goals_per_shot',
#  'goals_per_shot_on_target',
#  'passes_completed',
#  'passes_pct',
#  'passes_into_final_third',
#  'passes_into_penalty_area',
#  'progressive_passes',
#  'passes_live',
#  'passes_dead',
#  'through_balls',
#  'passes_switches',
#  'crosses',
#  'corner_kicks',
#  'dribble_tackles',
#  'dribbles_vs',
#  'dribble_tackles_pct',
#  'dribbled_past',
#  'blocks',
#  'blocked_shots',
#  'blocked_passes',
#  'interceptions',
#  'clearances',
#  'errors',
#  'touches',
#  'touches_def_pen_area',
#  'touches_def_3rd',
#  'touches_mid_3rd',
#  'touches_att_3rd',
#  'touches_att_pen_area',
#  'touches_live_ball',
#  'dribbles_completed',
#  'dribbles',
#  'dribbles_completed_pct',
#  'carries',
#  'progressive_carries',
#  'carries_into_final_third',
#  'carries_into_penalty_area',
#  'passes_received',
#  'miscontrols',
#  'dispossessed',
#  'fouls',
#  'fouled',
#  'aerials_won',
#  'aerials_lost',
#  'aerials_won_pct',
#  'team_possession',
#  'team_goals_assists_per90',
#  'team_goals_pens_per90',
#  'team_goals_assists_pens_per90',
#  'team_xg_per90',
#  'team_gk_goals_against_per90',
#  'team_gk_save_pct',
#  'team_gk_clean_sheets_pct',
#  'team_passes_pct',
#  'team_passes_pct_medium',
#  'team_passes_pct_long',
#  'team_sca_per90',
#  'team_gca_per90',
#  'team_dribble_tackles_pct',
#  'team_aerials_won_pct',
#  'vs_team_possession',
#  'vs_team_goals_per90',
#  'vs_team_assists_per90',
#  'vs_team_xg_per90',
#  'vs_team_gk_save_pct',
#  'vs_team_gk_clean_sheets_pct',
#  'vs_team_gk_pct_passes_launched',
#  'vs_team_gk_crosses_stopped_pct',
#  'vs_team_shots_on_target_per90',
#  'vs_team_passes_pct',
#  'vs_team_passes_pct_short',
#  'vs_team_passes_pct_medium',
#  'vs_team_passes_pct_long',
#  'vs_team_sca_per90',
#  'vs_team_gca_per90',
#  'vs_team_dribble_tackles_pct',
#  'vs_team_dribbles_completed_pct',
#  'vs_team_aerials_won_pct']

# %%
features_abs = ['r',
 'games',
 'games_starts',                
 'minutes',
 'shots_on_target_pct',
 'goals_per_shot',
 'goals_per_shot_on_target',
 'passes_pct',
 #'dribble_tackles_pct',
 #'dribbles_completed_pct',
 'aerials_won_pct',
 'team_possession',
 'team_goals_assists_per90',
 'team_goals_pens_per90',
 'team_goals_assists_pens_per90',
 'team_xg_per90',
 'team_gk_goals_against_per90',
 'team_gk_save_pct',
 'team_gk_clean_sheets_pct',
 'team_passes_pct',
 'team_passes_pct_medium',
 'team_passes_pct_long',
 'team_sca_per90',
 'team_gca_per90',
 #'team_dribble_tackles_pct',
 'team_aerials_won_pct',
 'vs_team_possession',
 'vs_team_goals_per90',
 'vs_team_assists_per90',
 'vs_team_xg_per90',
 'vs_team_gk_save_pct',
 'vs_team_gk_clean_sheets_pct',
 'vs_team_gk_pct_passes_launched',
 'vs_team_gk_crosses_stopped_pct',
 'vs_team_shots_on_target_per90',
 'vs_team_passes_pct',
 'vs_team_passes_pct_short',
 'vs_team_passes_pct_medium',
 'vs_team_passes_pct_long',
 'vs_team_sca_per90',
 'vs_team_gca_per90',
 #'vs_team_dribble_tackles_pct',
 #'vs_team_dribbles_completed_pct',
 'vs_team_aerials_won_pct',
 'opp_team_possession',
 'opp_team_goals_assists_per90',
 'opp_team_goals_pens_per90',
 'opp_team_goals_assists_pens_per90',
 'opp_team_xg_per90',
 'opp_team_gk_goals_against_per90',
 'opp_team_gk_save_pct',
 'opp_team_gk_clean_sheets_pct',
 'opp_team_passes_pct',
 'opp_team_passes_pct_medium',
 'opp_team_passes_pct_long',
 'opp_team_sca_per90',
 'opp_team_gca_per90',
 #'opp_team_dribble_tackles_pct',
 'opp_team_aerials_won_pct',
 'opp_vs_team_possession',
 'opp_vs_team_goals_per90',
 'opp_vs_team_assists_per90',
 'opp_vs_team_xg_per90',
 'opp_vs_team_gk_save_pct',
 'opp_vs_team_gk_clean_sheets_pct',
 'opp_vs_team_gk_pct_passes_launched',
 'opp_vs_team_gk_crosses_stopped_pct',
 'opp_vs_team_shots_on_target_per90',
 'opp_vs_team_passes_pct',
 'opp_vs_team_passes_pct_short',
 'opp_vs_team_passes_pct_medium',
 'opp_vs_team_passes_pct_long',
 'opp_vs_team_sca_per90',
 'opp_vs_team_gca_per90',
 #'opp_vs_team_dribble_tackles_pct',
 #'opp_vs_team_dribbles_completed_pct',
 'opp_vs_team_aerials_won_pct',
                
 'vote_avg',
 'vote_std']

features_rel = [
 'goals',
 'assists',
 'cards_yellow',
 'cards_red',
 'xg',
 'npxg',
 'shots_on_target',
 'passes_completed',
 'passes_into_final_third',
 'passes_into_penalty_area',
 'progressive_passes',
 'passes_live',
 'passes_dead',
 'through_balls',
 'passes_switches',
 'crosses',
 'corner_kicks',
 #'dribble_tackles',
 #'dribbles_vs',
 #'dribbled_past',
 'blocks',
 'blocked_shots',
 'blocked_passes',
 'interceptions',
 'clearances',
 'errors',
 'touches',
 'touches_def_pen_area',
 'touches_def_3rd',
 'touches_mid_3rd',
 'touches_att_3rd',
 'touches_att_pen_area',
 'touches_live_ball',
 #'dribbles_completed',
 #'dribbles',
 'passes_received',
 'miscontrols',
 'dispossessed',
 'fouls',
 'fouled',
 'aerials_won',
 'aerials_lost',
 'carries',
 'progressive_carries',
 'carries_into_final_third',
 'carries_into_penalty_area']

features_rel_gamecorr = [
    'goals',
    'assists',
    'xg',
    'npxg',
    'cards_yellow',
    'cards_red'
]

# %%
def player_match_data_ext(player, pteam, oppteam):
    pdata = player_match_data(player, pteam, oppteam)
    
    if(not isinstance(pdata, pd.DataFrame)):
        return None
    
    out = pd.concat([pdata[features_abs], pdata[features_rel]], axis = 1)
    
    out[features_rel] = out[features_rel] / max(pdata['minutes'][0], 1)
    
    out[features_rel_gamecorr] = out[features_rel_gamecorr] * (pdata['minutes'][0] / max(pdata['games'][0], 1) / 90)
    
    return out

# %%
test = player_match_data_ext('Immobile', 'Lazio', 'Atalanta')

add_columns = test.columns

test
# Out:
#           r  games  games_starts  minutes  shots_on_target_pct  \
# Immobile  A     31            21     1652                 42.2
#
#           goals_per_shot  goals_per_shot_on_target  passes_pct  \
# Immobile            0.07                      0.16        73.3
#
#           aerials_won_pct  team_possession  ...  miscontrols  dispossessed  \
# Immobile             33.3             53.3  ...     0.031477      0.008475
#
#              fouls    fouled  aerials_won  aerials_lost   carries  \
# Immobile  0.013317  0.018765     0.008475      0.016949  0.197942
#
#           progressive_carries  carries_into_final_third  \
# Immobile             0.011501                  0.007869
#
#           carries_into_penalty_area
# Immobile                   0.008475
#
# [1 rows x 112 columns]

# %%
votes = pd.read_excel('mid_outputs/season' + season + '/players_votes.xlsx', index_col = 0)
votes
# Out:
#        matchday       player      team   oppteam  home  vote  goals  assists  \
# 0             1        Musso  Atalanta  Sassuolo     0   6.5      0        0
# 1             1   Zappacosta  Atalanta  Sassuolo     0   6.5      0        0
# 2             1     Djimsiti  Atalanta  Sassuolo     0   6.0      0        0
# 3             1    Kolasinac  Atalanta  Sassuolo     0   6.5      0        0
# 4             1       Zortea  Atalanta  Sassuolo     0   7.0      1        0
# ...         ...          ...       ...       ...   ...   ...    ...      ...
# 10800        38      Charlys    Verona     Inter     1   6.0      0        0
# 10801        38   Dani Silva    Verona     Inter     1   6.0      0        0
# 10802        38  Mitrovic S.    Verona     Inter     1   6.5      0        0
# 10803        38       Noslin    Verona     Inter     1   7.5      1        1
# 10804        38       Tavsan    Verona     Inter     1   6.0      0        0
#
#        cards_malus  fantavote
# 0              0.0        6.5
# 1              0.0        6.5
# 2              0.0        6.0
# 3              0.0        6.5
# 4              0.0       10.0
# ...            ...        ...
# 10800          0.0        6.0
# 10801          0.0        6.0
# 10802          0.0        6.5
# 10803          0.0       11.5
# 10804          0.0        6.0
#
# [10805 rows x 10 columns]

# %%
db = votes.copy()

delta = pd.DataFrame(columns = add_columns)

for i in range(db.shape[0]):
    ext_data = player_match_data_ext(db['player'][i], db['team'][i], db['oppteam'][i])
    
    if(not isinstance(ext_data, pd.DataFrame)):
        continue
    
    ext_data = ext_data.rename(index = {db['player'][i] : i})
    
    delta = pd.concat([delta, ext_data], axis = 0)
    
    if(i % 100 == 0):
        print(i)
    
db = pd.concat([db, delta], axis = 1)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10300
# 10400
# 10500
# 10600
# 10700

# %%
db
# Out:
#        matchday       player      team   oppteam  home  vote  goals  assists  \
# 0             1        Musso  Atalanta  Sassuolo     0   6.5      0        0
# 1             1   Zappacosta  Atalanta  Sassuolo     0   6.5      0        0
# 2             1     Djimsiti  Atalanta  Sassuolo     0   6.0      0        0
# 3             1    Kolasinac  Atalanta  Sassuolo     0   6.5      0        0
# 4             1       Zortea  Atalanta  Sassuolo     0   7.0      1        0
# ...         ...          ...       ...       ...   ...   ...    ...      ...
# 10800        38      Charlys    Verona     Inter     1   6.0      0        0
# 10801        38   Dani Silva    Verona     Inter     1   6.0      0        0
# 10802        38  Mitrovic S.    Verona     Inter     1   6.5      0        0
# 10803        38       Noslin    Verona     Inter     1   7.5      1        1
# 10804        38       Tavsan    Verona     Inter     1   6.0      0        0
#
#        cards_malus  fantavote  ... miscontrols dispossessed     fouls  \
# 0              0.0        6.5  ...    0.000000     0.000000  0.000000
# 1              0.0        6.5  ...    0.014462     0.008034  0.013926
# 2              0.0        6.0  ...    0.002472     0.001059  0.006003
# 3              0.0        6.5  ...    0.008724     0.004132  0.013315
# 4              0.0       10.0  ...    0.013423     0.013423  0.026846
# ...            ...        ...  ...         ...          ...       ...
# 10800          0.0        6.0  ...         NaN          NaN       NaN
# 10801          0.0        6.0  ...         NaN          NaN       NaN
# 10802          0.0        6.5  ...         NaN          NaN       NaN
# 10803          0.0       11.5  ...         NaN          NaN       NaN
# 10804          0.0        6.0  ...         NaN          NaN       NaN
#
#          fouled  aerials_won  aerials_lost   carries  progressive_carries  \
# 0      0.000000     0.000000      0.000000  0.000000             0.000000
# 1      0.008034     0.004821      0.006963  0.364221             0.035886
# 2      0.003884     0.032486      0.019421  0.336511             0.002119
# 3      0.009183     0.015611      0.014692  0.343893             0.014692
# 4      0.013423     0.000000      0.013423  0.489933             0.046980
# ...         ...          ...           ...       ...                  ...
# 10800       NaN          NaN           NaN       NaN                  NaN
# 10801       NaN          NaN           NaN       NaN                  NaN
# 10802       NaN          NaN           NaN       NaN                  NaN
# 10803       NaN          NaN           NaN       NaN                  NaN
# 10804       NaN          NaN           NaN       NaN                  NaN
#
#        carries_into_final_third  carries_into_penalty_area
# 0                      0.000000                   0.000000
# 1                      0.017675                   0.007499
# 2                      0.003531                   0.000000
# 3                      0.011019                   0.002296
# 4                      0.060403                   0.006711
# ...                         ...                        ...
# 10800                       NaN                        NaN
# 10801                       NaN                        NaN
# 10802                       NaN                        NaN
# 10803                       NaN                        NaN
# 10804                       NaN                        NaN
#
# [10805 rows x 122 columns]

# %%
db = db.drop(db[db.r == 'P'].index) # remove goalkeepers
db = db.drop(db[db.r != db.r].index) # remove non extisting players
db = db.drop(db[db.r != db.r].index) # remove non extisting players
db = db.drop(db[db.xg != db.xg].index)

# %%
db
# Out:
#        matchday      player      team   oppteam  home  vote  goals  assists  \
# 1             1  Zappacosta  Atalanta  Sassuolo     0   6.5      0        0
# 2             1    Djimsiti  Atalanta  Sassuolo     0   6.0      0        0
# 3             1   Kolasinac  Atalanta  Sassuolo     0   6.5      0        0
# 4             1      Zortea  Atalanta  Sassuolo     0   7.0      1        0
# 5             1     Ruggeri  Atalanta  Sassuolo     0   6.5      0        1
# ...         ...         ...       ...       ...   ...   ...    ...      ...
# 10794        38       Cabal    Verona     Inter     1   5.5      0        0
# 10795        38     Lazovic    Verona     Inter     1   5.5      0        0
# 10797        38      Serdar    Verona     Inter     1   6.5      0        0
# 10798        38  Tchatchoua    Verona     Inter     1   6.0      0        0
# 10799        38      Suslov    Verona     Inter     1   7.5      1        1
#
#        cards_malus  fantavote  ... miscontrols dispossessed     fouls  \
# 1              0.0        6.5  ...    0.014462     0.008034  0.013926
# 2              0.0        6.0  ...    0.002472     0.001059  0.006003
# 3              0.0        6.5  ...    0.008724     0.004132  0.013315
# 4              0.0       10.0  ...    0.013423     0.013423  0.026846
# 5              0.0        7.5  ...    0.011842     0.004083  0.008575
# ...            ...        ...  ...         ...          ...       ...
# 10794          0.5        5.0  ...    0.014696     0.007348  0.018036
# 10795          0.0        5.5  ...    0.011411     0.008299  0.002593
# 10797          0.0        6.5  ...    0.012658     0.007836  0.024111
# 10798          0.0        6.0  ...    0.005217     0.002899  0.010435
# 10799          0.0       11.5  ...    0.027247     0.016252  0.019120
#
#          fouled  aerials_won  aerials_lost   carries  progressive_carries  \
# 1      0.008034     0.004821      0.006963  0.364221             0.035886
# 2      0.003884     0.032486      0.019421  0.336511             0.002119
# 3      0.009183     0.015611      0.014692  0.343893             0.014692
# 4      0.013423     0.000000      0.013423  0.489933             0.046980
# 5      0.003675     0.020008      0.014700  0.351980             0.022458
# ...         ...          ...           ...       ...                  ...
# 10794  0.010688     0.038744      0.014028  0.275217             0.017368
# 10795  0.002593     0.004149      0.007780  0.229772             0.022303
# 10797  0.010850     0.013261      0.012658  0.235081             0.012055
# 10798  0.004058     0.007536      0.007536  0.237681             0.019710
# 10799  0.026769     0.002390      0.005736  0.241874             0.021989
#
#        carries_into_final_third  carries_into_penalty_area
# 1                      0.017675                   0.007499
# 2                      0.003531                   0.000000
# 3                      0.011019                   0.002296
# 4                      0.060403                   0.006711
# 5                      0.016333                   0.002042
# ...                         ...                        ...
# 10794                  0.011356                   0.000668
# 10795                  0.010892                   0.007261
# 10797                  0.009042                   0.001808
# 10798                  0.013913                   0.002899
# 10799                  0.021033                   0.006214
#
# [9655 rows x 122 columns]

# %%
db.to_excel('mid_outputs/season' + season + '/database_entries.xlsx')

# %% [markdown]
# Goalkeepers

# %%
features_abs_gk = [
 'gk_games',
 'gk_games_starts',
 'gk_minutes',
 'gk_goals_against_per90', 
 'gk_save_pct',
 'gk_clean_sheets_pct',
 'gk_psxg_net_per90',
 'gk_passes_pct_launched',
 'gk_pct_passes_launched',
 'gk_passes_length_avg',
 'gk_pct_goal_kicks_launched',
 'gk_goal_kick_length_avg',
 'gk_crosses_stopped_pct',
 'gk_def_actions_outside_pen_area_per90',
 'gk_avg_distance_def_actions',
    
 'team_possession',
 'team_goals_assists_per90',
 'team_goals_pens_per90',
 'team_goals_assists_pens_per90',
 'team_xg_per90',
 'team_gk_goals_against_per90',
 'team_gk_save_pct',
 'team_gk_clean_sheets_pct',
 'team_passes_pct',
 'team_passes_pct_medium',
 'team_passes_pct_long',
 'team_sca_per90',
 'team_gca_per90',
 #'team_dribble_tackles_pct',
 'team_aerials_won_pct',
 'vs_team_possession',
 'vs_team_goals_per90',
 'vs_team_assists_per90',
 'vs_team_xg_per90',
 'vs_team_gk_save_pct',
 'vs_team_gk_clean_sheets_pct',
 'vs_team_gk_pct_passes_launched',
 'vs_team_gk_crosses_stopped_pct',
 'vs_team_shots_on_target_per90',
 'vs_team_passes_pct',
 'vs_team_passes_pct_short',
 'vs_team_passes_pct_medium',
 'vs_team_passes_pct_long',
 'vs_team_sca_per90',
 'vs_team_gca_per90',
 #'vs_team_dribble_tackles_pct',
 #'vs_team_dribbles_completed_pct',
 'vs_team_aerials_won_pct',
 'opp_team_possession',
 'opp_team_goals_assists_per90',
 'opp_team_goals_pens_per90',
 'opp_team_goals_assists_pens_per90',
 'opp_team_xg_per90',
 'opp_team_gk_goals_against_per90',
 'opp_team_gk_save_pct',
 'opp_team_gk_clean_sheets_pct',
 'opp_team_passes_pct',
 'opp_team_passes_pct_medium',
 'opp_team_passes_pct_long',
 'opp_team_sca_per90',
 'opp_team_gca_per90',
 #'opp_team_dribble_tackles_pct',
 'opp_team_aerials_won_pct',
 'opp_vs_team_possession',
 'opp_vs_team_goals_per90',
 'opp_vs_team_assists_per90',
 'opp_vs_team_xg_per90',
 'opp_vs_team_gk_save_pct',
 'opp_vs_team_gk_clean_sheets_pct',
 'opp_vs_team_gk_pct_passes_launched',
 'opp_vs_team_gk_crosses_stopped_pct',
 'opp_vs_team_shots_on_target_per90',
 'opp_vs_team_passes_pct',
 'opp_vs_team_passes_pct_short',
 'opp_vs_team_passes_pct_medium',
 'opp_vs_team_passes_pct_long',
 'opp_vs_team_sca_per90',
 'opp_vs_team_gca_per90',
 #'opp_vs_team_dribble_tackles_pct',
 #'opp_vs_team_dribbles_completed_pct',
 'opp_vs_team_aerials_won_pct',
                
 'vote_avg',
 'vote_std']

features_rel_gk = [
 'gk_shots_on_target_against',
 'gk_saves',
 'gk_free_kick_goals_against',
 'gk_corner_kick_goals_against',
 'gk_own_goals_against',
 'gk_psxg',
 'gk_psnpxg_per_shot_on_target_against',
 'gk_psxg_net',
 'gk_passes_completed_launched',
 'gk_passes_launched',
 'gk_passes',
 'gk_passes_throws',
 'gk_goal_kicks',
 'gk_crosses',
 'gk_crosses_stopped',
]

# %%
def player_match_data_ext_gk(player, pteam, oppteam):
    pdata = player_match_data(player, pteam, oppteam)
    
    if(not isinstance(pdata, pd.DataFrame)):
        return None
    
    if(pdata['gk_games'][0] <= 0):
        return None
    
    out = pd.concat([pdata[features_abs_gk], pdata[features_rel_gk]], axis = 1)
    
    out[features_rel_gk] = out[features_rel_gk] / max(pdata['minutes'][0], 1)

    return out

# %%
test = player_match_data_ext_gk('Consigli', 'Sassuolo', 'Atalanta')

add_columns_gk = test.columns

test
# Out:
#           gk_games  gk_games_starts  gk_minutes  gk_goals_against_per90  \
# Consigli        35               35        3150                    1.94
#
#           gk_save_pct  gk_clean_sheets_pct  gk_psxg_net_per90  \
# Consigli         61.6                  8.6              -0.38
#
#           gk_passes_pct_launched  gk_pct_passes_launched  \
# Consigli                    31.9                    42.3
#
#           gk_passes_length_avg  ...  gk_psxg  \
# Consigli                  36.9  ...     51.7
#
#           gk_psnpxg_per_shot_on_target_against  gk_psxg_net  \
# Consigli                                  0.28        -13.3
#
#           gk_passes_completed_launched  gk_passes_launched  gk_passes  \
# Consigli                         172.0               540.0      982.0
#
#           gk_passes_throws  gk_goal_kicks  gk_crosses  gk_crosses_stopped
# Consigli             143.0          252.0       545.0                23.0
#
# [1 rows x 92 columns]

# %%
db_gk = votes.copy()

delta = pd.DataFrame(columns = add_columns_gk)

for i in range(db_gk.shape[0]):
    ext_data = player_match_data_ext_gk(db_gk['player'][i], db_gk['team'][i], db_gk['oppteam'][i])
    
    if(i % 100 == 0):
        print(i)
        
    if(not isinstance(ext_data, pd.DataFrame)):
        continue
    
    ext_data = ext_data.rename(index = {db_gk['player'][i] : i})
    
    delta = pd.concat([delta, ext_data], axis = 0)
    
    
    
db_gk = pd.concat([db_gk, delta], axis = 1)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800

# %%
db_gk = db_gk.drop(db_gk[db_gk.gk_games != db_gk.gk_games].index) # remove non extisting players

# %%
db_gk.to_excel('mid_outputs/season' + season + '/database_entries_gk.xlsx')
