# %% [markdown]
# Player/match dataset creation
#
# For each serie A (already happened) match and player, a database entry is generated, with this form:
#
# [y = player votes data, player data, team data, vs team data, opp team data, vs opp team data]

# %%
import pandas as pd

# %% [markdown]
# Load team data from FBref

# %%
rcsv = pd.read_csv('fbref_data/teams.csv')   
team = pd.DataFrame(rcsv)

rcsv = pd.read_csv('fbref_data/teams_vs.csv')   
vs_team = pd.DataFrame(rcsv)

for i in range(1, team.shape[1]):
    team = team.rename(columns = {team.columns[i] : 'team_' + team.columns[i]})
    
for i in range(1, vs_team.shape[1]):
    vs_team = vs_team.rename(columns = {vs_team.columns[i] : 'vs_team_' + vs_team.columns[i]})
    
vs_team.pop('team')

team_data = pd.concat([team, vs_team], axis = 1)

team_data['team_idx'] = team_data['team']
for i in range(team_data.shape[0]):
    team_data.loc[i, 'team_idx'] = team_data.loc[i, 'team_idx'].split(' ')[-1]

team_data = team_data.set_index('team_idx')

team_data
# Out:
#                      team  team_players_used  team_possession  team_games  \
# team_idx
# Atalanta         Atalanta               16.0             52.0         1.0
# Bologna           Bologna               16.0             73.0         1.0
# Cagliari         Cagliari               14.0             43.0         1.0
# Como                 Como               16.0             43.0         1.0
# Empoli             Empoli               16.0             39.0         1.0
# Fiorentina     Fiorentina               16.0             61.0         1.0
# Genoa               Genoa               15.0             32.0         1.0
# Verona      Hellas Verona               16.0             33.0         1.0
# Inter               Inter               16.0             68.0         1.0
# Juventus         Juventus               14.0             57.0         1.0
# Lazio               Lazio               16.0             67.0         1.0
# Lecce               Lecce               16.0             48.0         1.0
# Milan               Milan               16.0             56.0         1.0
# Monza               Monza               14.0             61.0         1.0
# Napoli             Napoli               15.0             67.0         1.0
# Parma               Parma               16.0             39.0         1.0
# Roma                 Roma               15.0             57.0         1.0
# Torino             Torino               16.0             44.0         1.0
# Udinese           Udinese               15.0             27.0         1.0
# Venezia           Venezia               16.0             33.0         1.0
#
#             team_games_starts  team_minutes  team_goals  team_assists  \
# team_idx
# Atalanta                 11.0          90.0         4.0           2.0
# Bologna                  11.0          90.0         1.0           0.0
# Cagliari                 11.0          90.0         0.0           0.0
# Como                     11.0          90.0         0.0           0.0
# Empoli                   11.0          90.0         0.0           0.0
# Fiorentina               11.0          90.0         1.0           0.0
# Genoa                    11.0          90.0         2.0           0.0
# Verona                   11.0          90.0         3.0           3.0
# Inter                    11.0          90.0         2.0           2.0
# Juventus                 11.0          90.0         3.0           2.0
# Lazio                    11.0          90.0         2.0           0.0
# Lecce                    11.0          90.0         0.0           0.0
# Milan                    11.0          90.0         2.0           1.0
# Monza                    11.0          90.0         0.0           0.0
# Napoli                   11.0          90.0         0.0           0.0
# Parma                    11.0          90.0         1.0           1.0
# Roma                     11.0          90.0         0.0           0.0
# Torino                   11.0          90.0         1.0           1.0
# Udinese                  11.0          90.0         1.0           1.0
# Venezia                  11.0          90.0         1.0           1.0
#
#             team_pens_made  team_pens_att  ...  vs_team_fouls  vs_team_fouled  \
# team_idx                                   ...
# Atalanta               1.0            1.0  ...           10.0            24.0
# Bologna                1.0            1.0  ...           17.0            16.0
# Cagliari               0.0            0.0  ...            7.0            15.0
# Como                   0.0            0.0  ...           11.0            12.0
# Empoli                 0.0            0.0  ...           19.0            16.0
# Fiorentina             0.0            0.0  ...           15.0             9.0
# Genoa                  0.0            1.0  ...           16.0            12.0
# Verona                 0.0            0.0  ...           13.0            15.0
# Inter                  0.0            0.0  ...           16.0            14.0
# Juventus               0.0            0.0  ...           12.0            11.0
# Lazio                  1.0            1.0  ...           11.0            13.0
# Lecce                  0.0            0.0  ...           24.0            10.0
# Milan                  0.0            0.0  ...            7.0            10.0
# Monza                  0.0            0.0  ...           16.0            18.0
# Napoli                 0.0            0.0  ...           15.0            13.0
# Parma                  0.0            0.0  ...            9.0            11.0
# Roma                   0.0            0.0  ...           15.0             7.0
# Torino                 0.0            0.0  ...           10.0             7.0
# Udinese                0.0            1.0  ...           17.0            16.0
# Venezia                0.0            0.0  ...           14.0            10.0
#
#             vs_team_offsides  vs_team_pens_won  vs_team_pens_conceded  \
# team_idx
# Atalanta                 1.0               0.0                    1.0
# Bologna                  1.0               1.0                    1.0
# Cagliari                 2.0               0.0                    0.0
# Como                     4.0               0.0                    0.0
# Empoli                   1.0               0.0                    0.0
# Fiorentina               1.0               0.0                    0.0
# Genoa                    6.0               0.0                    1.0
# Verona                   0.0               0.0                    0.0
# Inter                    0.0               0.0                    0.0
# Juventus                 1.0               0.0                    0.0
# Lazio                    1.0               0.0                    1.0
# Lecce                    1.0               1.0                    0.0
# Milan                    1.0               0.0                    0.0
# Monza                    4.0               0.0                    0.0
# Napoli                   2.0               0.0                    0.0
# Parma                    5.0               0.0                    0.0
# Roma                     3.0               0.0                    0.0
# Torino                   2.0               0.0                    0.0
# Udinese                  1.0               1.0                    1.0
# Venezia                  0.0               1.0                    0.0
#
#             vs_team_own_goals  vs_team_ball_recoveries  vs_team_aerials_won  \
# team_idx
# Atalanta                  0.0                     41.0                 23.0
# Bologna                   0.0                     31.0                 10.0
# Cagliari                  0.0                     37.0                 10.0
# Como                      0.0                     34.0                 12.0
# Empoli                    0.0                     30.0                 22.0
# Fiorentina                0.0                     35.0                  8.0
# Genoa                     0.0                     31.0                 24.0
# Verona                    0.0                     39.0                 23.0
# Inter                     0.0                     27.0                 12.0
# Juventus                  0.0                     24.0                  3.0
# Lazio                     1.0                     33.0                 10.0
# Lecce                     0.0                     46.0                 20.0
# Milan                     0.0                     21.0                  8.0
# Monza                     0.0                     41.0                 16.0
# Napoli                    0.0                     44.0                 13.0
# Parma                     0.0                     43.0                 11.0
# Roma                      0.0                     41.0                 11.0
# Torino                    1.0                     37.0                 20.0
# Udinese                   0.0                     44.0                 16.0
# Venezia                   0.0                     36.0                 12.0
#
#             vs_team_aerials_lost  vs_team_aerials_won_pct
# team_idx
# Atalanta                    20.0                     53.5
# Bologna                     16.0                     38.5
# Cagliari                    11.0                     47.6
# Como                         3.0                     80.0
# Empoli                      16.0                     57.9
# Fiorentina                  11.0                     42.1
# Genoa                       12.0                     66.7
# Verona                      13.0                     63.9
# Inter                       24.0                     33.3
# Juventus                    12.0                     20.0
# Lazio                       12.0                     45.5
# Lecce                       23.0                     46.5
# Milan                       20.0                     28.6
# Monza                       22.0                     42.1
# Napoli                      23.0                     36.1
# Parma                        8.0                     57.9
# Roma                        10.0                     52.4
# Torino                       8.0                     71.4
# Udinese                     10.0                     61.5
# Venezia                     10.0                     54.5
#
# [20 rows x 303 columns]

# %%
team_data.to_excel('mid_outputs/team_data.xlsx')

# %% [markdown]
# Load data generated from players_dataset_creation

# %%
rx = pd.read_excel('mid_outputs/players_stats.xlsx', index_col = 3)   
players = pd.DataFrame(rx)

players
# Out:
#              Unnamed: 0    id  r      team      surname initial  fb_ID  \
# name
# Sommer                0  2428  P     Inter       Sommer     NaN    325
# Di Gregorio           1  5876  P  Juventus     Gregorio     NaN    310
# Maignan               2  4312  P     Milan      Maignan     NaN    314
# Meret                 3   572  P    Napoli        Meret     NaN    315
# Svilar                4  5841  P      Roma       Svilar     NaN    327
# ...                 ...   ... ..       ...          ...     ...    ...
# Mutandwa            511  6598  A  Cagliari     Mutandwa     NaN     -1
# Joao Costa          512  6603  A      Roma        Costa     NaN     -1
# Jasim               513  6648  A      Como        Jasim     NaN     -1
# Charpentier         514  6670  A     Parma  Charpentier     NaN     -1
# Ekhator             515  6822  A     Genoa      Ekhator     NaN     97
#
#                 age  birth_year  games  ...  gk_pct_goal_kicks_launched  \
# name                                    ...
# Sommer       35-250        1988      0  ...                        25.0
# Di Gregorio  27-027        1997      0  ...                        42.9
# Maignan      29-051        1995      0  ...                        50.0
# Meret        27-154        1997      0  ...                        25.0
# Svilar       24-362        1999      0  ...                        62.5
# ...             ...         ...    ...  ...                         ...
# Mutandwa          0           0      0  ...                         0.0
# Joao Costa        0           0      0  ...                         0.0
# Jasim             0           0      0  ...                         0.0
# Charpentier       0           0      0  ...                         0.0
# Ekhator      17-286        2006      1  ...                         0.0
#
#              gk_goal_kick_length_avg  gk_crosses  gk_crosses_stopped  \
# name
# Sommer                          30.0          11                   0
# Di Gregorio                     37.3          10                   1
# Maignan                         41.0           7                   1
# Meret                           24.3           5                   1
# Svilar                          51.6          13                   0
# ...                              ...         ...                 ...
# Mutandwa                         0.0           0                   0
# Joao Costa                       0.0           0                   0
# Jasim                            0.0           0                   0
# Charpentier                      0.0           0                   0
# Ekhator                          0.0           0                   0
#
#              gk_crosses_stopped_pct  gk_def_actions_outside_pen_area  \
# name
# Sommer                          0.0                                1
# Di Gregorio                    10.0                                0
# Maignan                        14.3                                4
# Meret                          20.0                                2
# Svilar                          0.0                                0
# ...                             ...                              ...
# Mutandwa                        0.0                                0
# Joao Costa                      0.0                                0
# Jasim                           0.0                                0
# Charpentier                     0.0                                0
# Ekhator                         0.0                                0
#
#              gk_def_actions_outside_pen_area_per90  \
# name
# Sommer                                           1
# Di Gregorio                                      0
# Maignan                                          4
# Meret                                            2
# Svilar                                           0
# ...                                            ...
# Mutandwa                                         0
# Joao Costa                                       0
# Jasim                                            0
# Charpentier                                      0
# Ekhator                                          0
#
#              gk_avg_distance_def_actions  vote_avg  vote_std
# name
# Sommer                              21.5  5.500000         0
# Di Gregorio                          4.0  6.000000         0
# Maignan                             22.0  7.000000         0
# Meret                               21.2  6.000000         0
# Svilar                              15.0  6.500000         0
# ...                                  ...       ...       ...
# Mutandwa                             0.0  6.122651         0
# Joao Costa                           0.0  5.274221         0
# Jasim                                0.0  5.110230         0
# Charpentier                          0.0  6.094636         0
# Ekhator                              0.0  6.096227         0
#
# [516 rows x 160 columns]

# %% [markdown]
# Function for merging match data (player, team, opponent team)

# %%
def player_match_data(player, pteam, oppteam):
    if(not(player in players.index)):
        return None
    
    pdata = players.loc[[player]]
    
    pteam_stats = team_data.loc[[pteam]].rename(index = {pteam : player})
    
    oppteam_stats = team_data.loc[[oppteam]].rename(index = {oppteam : player})
    
    oppteam_stats = oppteam_stats.rename(lambda x: 'opp_' + x, axis='columns')
    
    out = pd.concat([pdata, pteam_stats, oppteam_stats], axis = 1)
    
    return(out)

# %% [markdown]
# Output to excel file data for a player.
#
# The file is copied and there the desired features are manually selected and printed.

# %%
test = player_match_data('Barella', 'Inter', 'Atalanta')
test.to_excel('tmp/playermatchdata.xlsx')

test
# Out:
#          Unnamed: 0    id  r   team  surname initial  fb_ID     age  \
# Barella         254  1870  C  Inter  Barella     NaN     21  27-198
#
#          birth_year  games  ...  opp_vs_team_fouls  opp_vs_team_fouled  \
# Barella        1997      1  ...               10.0                24.0
#
#          opp_vs_team_offsides  opp_vs_team_pens_won  \
# Barella                   1.0                   0.0
#
#          opp_vs_team_pens_conceded  opp_vs_team_own_goals  \
# Barella                        1.0                    0.0
#
#          opp_vs_team_ball_recoveries  opp_vs_team_aerials_won  \
# Barella                         41.0                     23.0
#
#          opp_vs_team_aerials_lost  opp_vs_team_aerials_won_pct
# Barella                      20.0                         53.5
#
# [1 rows x 766 columns]

# %%
pteam = 'Inter'
pteam_stats = team_data.loc[[pteam]]
pteam_stats.index[0]
# Out:
# 'Inter'

# %%
rx = pd.read_excel('tmp/playermatchdata_sel.xlsx', index_col = 0, header = None)   

out = list()

for i in range(1, rx.shape[1]):
        if(rx[i][2] == "x"):
            out.append(rx[i][0])
            
out
# Out:
# ['r',
#  'fb_ID',
#  'games',
#  'games_starts',
#  'minutes',
#  'goals',
#  'assists',
#  'cards_yellow',
#  'cards_red',
#  'xg',
#  'npxg',
#  'shots_on_target',
#  'shots_on_target_pct',
#  'goals_per_shot',
#  'goals_per_shot_on_target',
#  'passes_completed',
#  'passes_pct',
#  'passes_into_final_third',
#  'passes_into_penalty_area',
#  'progressive_passes',
#  'passes_live',
#  'passes_dead',
#  'through_balls',
#  'passes_switches',
#  'crosses',
#  'corner_kicks',
#  'dribble_tackles',
#  'dribbles_vs',
#  'dribble_tackles_pct',
#  'dribbled_past',
#  'blocks',
#  'blocked_shots',
#  'blocked_passes',
#  'interceptions',
#  'clearances',
#  'errors',
#  'touches',
#  'touches_def_pen_area',
#  'touches_def_3rd',
#  'touches_mid_3rd',
#  'touches_att_3rd',
#  'touches_att_pen_area',
#  'touches_live_ball',
#  'dribbles_completed',
#  'dribbles',
#  'dribbles_completed_pct',
#  'carries',
#  'progressive_carries',
#  'carries_into_final_third',
#  'carries_into_penalty_area',
#  'passes_received',
#  'miscontrols',
#  'dispossessed',
#  'fouls',
#  'fouled',
#  'aerials_won',
#  'aerials_lost',
#  'aerials_won_pct',
#  'team_possession',
#  'team_goals_assists_per90',
#  'team_goals_pens_per90',
#  'team_goals_assists_pens_per90',
#  'team_xg_per90',
#  'team_gk_goals_against_per90',
#  'team_gk_save_pct',
#  'team_gk_clean_sheets_pct',
#  'team_passes_pct',
#  'team_passes_pct_medium',
#  'team_passes_pct_long',
#  'team_sca_per90',
#  'team_gca_per90',
#  'team_dribble_tackles_pct',
#  'team_aerials_won_pct',
#  'vs_team_possession',
#  'vs_team_goals_per90',
#  'vs_team_assists_per90',
#  'vs_team_xg_per90',
#  'vs_team_gk_save_pct',
#  'vs_team_gk_clean_sheets_pct',
#  'vs_team_gk_pct_passes_launched',
#  'vs_team_gk_crosses_stopped_pct',
#  'vs_team_shots_on_target_per90',
#  'vs_team_passes_pct',
#  'vs_team_passes_pct_short',
#  'vs_team_passes_pct_medium',
#  'vs_team_passes_pct_long',
#  'vs_team_sca_per90',
#  'vs_team_gca_per90',
#  'vs_team_dribble_tackles_pct',
#  'vs_team_dribbles_completed_pct',
#  'vs_team_aerials_won_pct']

# %% [markdown]
# Define and select the dataset features: abs features and rel features.
#
# Rel features are divided by the player minutes played.
#
# Rel features (game corrected) are divided by the player number of games instead of minutes.
# For example, a player who plays 20 minutes and scores, would be to match for stats averaging. It is better to consider the goals made per match.

# %%
features_abs = ['r',
 'games',
 'games_starts',                
 'minutes',
 'shots_on_target_pct',
 'goals_per_shot',
 'goals_per_shot_on_target',
 'passes_pct',
 #'dribble_tackles_pct',
 #'dribbles_completed_pct',
 'aerials_won_pct',
 'team_possession',
 'team_goals_assists_per90',
 'team_goals_pens_per90',
 'team_goals_assists_pens_per90',
 'team_xg_per90',
 'team_gk_goals_against_per90',
 'team_gk_save_pct',
 'team_gk_clean_sheets_pct',
 'team_passes_pct',
 'team_passes_pct_medium',
 'team_passes_pct_long',
 'team_sca_per90',
 'team_gca_per90',
 #'team_dribble_tackles_pct',
 'team_aerials_won_pct',
 'vs_team_possession',
 'vs_team_goals_per90',
 'vs_team_assists_per90',
 'vs_team_xg_per90',
 'vs_team_gk_save_pct',
 'vs_team_gk_clean_sheets_pct',
 'vs_team_gk_pct_passes_launched',
 'vs_team_gk_crosses_stopped_pct',
 'vs_team_shots_on_target_per90',
 'vs_team_passes_pct',
 'vs_team_passes_pct_short',
 'vs_team_passes_pct_medium',
 'vs_team_passes_pct_long',
 'vs_team_sca_per90',
 'vs_team_gca_per90',
 #'vs_team_dribble_tackles_pct',
 #'vs_team_dribbles_completed_pct',
 'vs_team_aerials_won_pct',
 'opp_team_possession',
 'opp_team_goals_assists_per90',
 'opp_team_goals_pens_per90',
 'opp_team_goals_assists_pens_per90',
 'opp_team_xg_per90',
 'opp_team_gk_goals_against_per90',
 'opp_team_gk_save_pct',
 'opp_team_gk_clean_sheets_pct',
 'opp_team_passes_pct',
 'opp_team_passes_pct_medium',
 'opp_team_passes_pct_long',
 'opp_team_sca_per90',
 'opp_team_gca_per90',
 #'opp_team_dribble_tackles_pct',
 'opp_team_aerials_won_pct',
 'opp_vs_team_possession',
 'opp_vs_team_goals_per90',
 'opp_vs_team_assists_per90',
 'opp_vs_team_xg_per90',
 'opp_vs_team_gk_save_pct',
 'opp_vs_team_gk_clean_sheets_pct',
 'opp_vs_team_gk_pct_passes_launched',
 'opp_vs_team_gk_crosses_stopped_pct',
 'opp_vs_team_shots_on_target_per90',
 'opp_vs_team_passes_pct',
 'opp_vs_team_passes_pct_short',
 'opp_vs_team_passes_pct_medium',
 'opp_vs_team_passes_pct_long',
 'opp_vs_team_sca_per90',
 'opp_vs_team_gca_per90',
 #'opp_vs_team_dribble_tackles_pct',
 #'opp_vs_team_dribbles_completed_pct',
 'opp_vs_team_aerials_won_pct',
                
 'vote_avg',
 'vote_std']

features_rel = [
 'goals',
 'assists',
 'cards_yellow',
 'cards_red',
 'xg',
 'npxg',
 'shots_on_target',
 'passes_completed',
 'passes_into_final_third',
 'passes_into_penalty_area',
 'progressive_passes',
 'passes_live',
 'passes_dead',
 'through_balls',
 'passes_switches',
 'crosses',
 'corner_kicks',
 #'dribble_tackles',
 #'dribbles_vs',
 #'dribbled_past',
 'blocks',
 'blocked_shots',
 'blocked_passes',
 'interceptions',
 'clearances',
 'errors',
 'touches',
 'touches_def_pen_area',
 'touches_def_3rd',
 'touches_mid_3rd',
 'touches_att_3rd',
 'touches_att_pen_area',
 'touches_live_ball',
 #'dribbles_completed',
 #'dribbles',
 'passes_received',
 'miscontrols',
 'dispossessed',
 'fouls',
 'fouled',
 'aerials_won',
 'aerials_lost',
 'carries',
 'progressive_carries',
 'carries_into_final_third',
 'carries_into_penalty_area']

features_rel_gamecorr = [
    'goals',
    'assists',
    'xg',
    'npxg',
    'cards_yellow',
    'cards_red'
]

# %% [markdown]
# Function for merging match data (player, team, opponent team) and select only the desired features, applying the desired corrections.

# %%
def player_match_data_ext(player, pteam, oppteam):
    pdata = player_match_data(player, pteam, oppteam)
    
    if(not isinstance(pdata, pd.DataFrame)):
        return None
    
    out = pd.concat([pdata[features_abs], pdata[features_rel]], axis = 1)
    
    out[features_rel] = out[features_rel] / max(pdata['minutes'][0], 1)
    
    out[features_rel_gamecorr] = out[features_rel_gamecorr] * (pdata['minutes'][0] / max(pdata['games'][0], 1) / 90)
    
    return out

# %% [markdown]
# Columns variable for the match data, to be then added to votes data.

# %%
test = player_match_data_ext('Barella', 'Inter', 'Atalanta')

add_columns = test.columns

test
# Out:
#          r  games  games_starts  minutes  shots_on_target_pct  goals_per_shot  \
# Barella  C      1             1       90                  0.0             0.0
#
#          goals_per_shot_on_target  passes_pct  aerials_won_pct  \
# Barella                       0.0        84.6              0.0
#
#          team_possession  ...  miscontrols  dispossessed  fouls    fouled  \
# Barella             68.0  ...     0.011111      0.022222    0.0  0.022222
#
#          aerials_won  aerials_lost   carries  progressive_carries  \
# Barella          0.0      0.022222  0.611111                  0.0
#
#          carries_into_final_third  carries_into_penalty_area
# Barella                       0.0                        0.0
#
# [1 rows x 112 columns]

# %% [markdown]
# Load Fantacalcio votes data for each match of the season.

# %%
votes = pd.read_excel('mid_outputs/players_votes.xlsx', index_col = 0)
votes
# Out:
#      matchday            player      team oppteam  home  vote  goals  assists  \
# 0           1             Musso  Atalanta   Lecce     0   6.0      0        0
# 1           1        Zappacosta  Atalanta   Lecce     0   6.5      0        0
# 2           1          Djimsiti  Atalanta   Lecce     0   6.0      0        0
# 3           1            Bakker  Atalanta   Lecce     0   6.0      0        0
# 4           1           Godfrey  Atalanta   Lecce     0   6.0      0        0
# ..        ...               ...       ...     ...   ...   ...    ...      ...
# 278         1            Serdar    Verona  Napoli     1   5.5      0        0
# 279         1            Suslov    Verona  Napoli     1   6.0      0        0
# 280         1          Mosquera    Verona  Napoli     1   7.5      2        0
# 281         1  Rocha Livramento    Verona  Napoli     1   7.0      1        0
# 282         1         Tengstedt    Verona  Napoli     1   5.5      0        0
#
#      cards_malus  fantavote
# 0            0.0        6.0
# 1            0.0        6.5
# 2            0.0        6.0
# 3            0.0        6.0
# 4            0.0        6.0
# ..           ...        ...
# 278          0.0        5.5
# 279          0.0        6.0
# 280          0.0       13.5
# 281          0.0       10.0
# 282          0.0        5.5
#
# [283 rows x 10 columns]

# %% [markdown]
# Merge votes data with match data for the player.

# %%
db = votes.copy()

delta = pd.DataFrame(columns = add_columns)

for i in range(db.shape[0]):
    ext_data = player_match_data_ext(db['player'][i], db['team'][i], db['oppteam'][i])
    
    if(not isinstance(ext_data, pd.DataFrame)):
        continue
    
    ext_data = ext_data.rename(index = {db['player'][i] : i})
    
    delta = pd.concat([delta, ext_data], axis = 0)
    
    if(i % 100 == 0):
        print(i)
    
db = pd.concat([db, delta], axis = 1)
# Out:
# 0
# 100
# 200

# %%
db
# Out:
#      matchday            player      team oppteam  home  vote  goals  assists  \
# 0           1             Musso  Atalanta   Lecce     0   6.0      0        0
# 1           1        Zappacosta  Atalanta   Lecce     0   6.5      0        0
# 2           1          Djimsiti  Atalanta   Lecce     0   6.0      0        0
# 3           1            Bakker  Atalanta   Lecce     0   6.0      0        0
# 4           1           Godfrey  Atalanta   Lecce     0   6.0      0        0
# ..        ...               ...       ...     ...   ...   ...    ...      ...
# 278         1            Serdar    Verona  Napoli     1   5.5      0        0
# 279         1            Suslov    Verona  Napoli     1   6.0      0        0
# 280         1          Mosquera    Verona  Napoli     1   7.5      2        0
# 281         1  Rocha Livramento    Verona  Napoli     1   7.0      1        0
# 282         1         Tengstedt    Verona  Napoli     1   5.5      0        0
#
#      cards_malus  fantavote  ... miscontrols dispossessed     fouls    fouled  \
# 0            0.0        6.0  ...    0.000000     0.000000  0.000000  0.000000
# 1            0.0        6.5  ...    0.014925     0.000000  0.000000  0.014925
# 2            0.0        6.0  ...    0.000000     0.000000  0.011111  0.022222
# 3            0.0        6.0  ...    0.000000     0.000000  0.045455  0.000000
# 4            0.0        6.0  ...    0.043478     0.000000  0.043478  0.000000
# ..           ...        ...  ...         ...          ...       ...       ...
# 278          0.0        5.5  ...    0.050000     0.000000  0.050000  0.000000
# 279          0.0        6.0  ...    0.060606     0.030303  0.000000  0.060606
# 280          0.0       13.5  ...    0.055556     0.000000  0.000000  0.000000
# 281          0.0       10.0  ...    0.013699     0.013699  0.013699  0.013699
# 282          0.0        5.5  ...    0.027778     0.000000  0.000000  0.000000
#
#      aerials_won  aerials_lost   carries  progressive_carries  \
# 0       0.000000      0.000000  0.000000             0.000000
# 1       0.000000      0.029851  0.253731             0.044776
# 2       0.022222      0.022222  0.422222             0.011111
# 3       0.045455      0.045455  0.272727             0.000000
# 4       0.000000      0.000000  0.217391             0.000000
# ..           ...           ...       ...                  ...
# 278     0.000000      0.000000  0.050000             0.000000
# 279     0.000000      0.030303  0.242424             0.000000
# 280     0.055556      0.111111  0.277778             0.000000
# 281     0.041096      0.109589  0.109589             0.013699
# 282     0.000000      0.083333  0.097222             0.000000
#
#      carries_into_final_third  carries_into_penalty_area
# 0                    0.000000                        0.0
# 1                    0.000000                        0.0
# 2                    0.022222                        0.0
# 3                    0.000000                        0.0
# 4                    0.000000                        0.0
# ..                        ...                        ...
# 278                  0.000000                        0.0
# 279                  0.030303                        0.0
# 280                  0.000000                        0.0
# 281                  0.000000                        0.0
# 282                  0.000000                        0.0
#
# [283 rows x 122 columns]

# %% [markdown]
# Remove undesired database entries.

# %%
db = db.drop(db[db.r == 'P'].index) # remove goalkeepers
db = db.drop(db[db.r != db.r].index) # remove non existing players (by searching NaN values)
db = db.drop(db[db.xg != db.xg].index)

# %%
db
# Out:
#      matchday            player      team oppteam  home  vote  goals  assists  \
# 1           1        Zappacosta  Atalanta   Lecce     0   6.5      0        0
# 2           1          Djimsiti  Atalanta   Lecce     0   6.0      0        0
# 3           1            Bakker  Atalanta   Lecce     0   6.0      0        0
# 4           1           Godfrey  Atalanta   Lecce     0   6.0      0        0
# 5           1           Ruggeri  Atalanta   Lecce     0   7.0      0        1
# ..        ...               ...       ...     ...   ...   ...    ...      ...
# 278         1            Serdar    Verona  Napoli     1   5.5      0        0
# 279         1            Suslov    Verona  Napoli     1   6.0      0        0
# 280         1          Mosquera    Verona  Napoli     1   7.5      2        0
# 281         1  Rocha Livramento    Verona  Napoli     1   7.0      1        0
# 282         1         Tengstedt    Verona  Napoli     1   5.5      0        0
#
#      cards_malus  fantavote  ... miscontrols dispossessed     fouls    fouled  \
# 1            0.0        6.5  ...    0.014925     0.000000  0.000000  0.014925
# 2            0.0        6.0  ...    0.000000     0.000000  0.011111  0.022222
# 3            0.0        6.0  ...    0.000000     0.000000  0.045455  0.000000
# 4            0.0        6.0  ...    0.043478     0.000000  0.043478  0.000000
# 5            0.0        8.0  ...    0.000000     0.000000  0.011111  0.000000
# ..           ...        ...  ...         ...          ...       ...       ...
# 278          0.0        5.5  ...    0.050000     0.000000  0.050000  0.000000
# 279          0.0        6.0  ...    0.060606     0.030303  0.000000  0.060606
# 280          0.0       13.5  ...    0.055556     0.000000  0.000000  0.000000
# 281          0.0       10.0  ...    0.013699     0.013699  0.013699  0.013699
# 282          0.0        5.5  ...    0.027778     0.000000  0.000000  0.000000
#
#      aerials_won  aerials_lost   carries  progressive_carries  \
# 1       0.000000      0.029851  0.253731             0.044776
# 2       0.022222      0.022222  0.422222             0.011111
# 3       0.045455      0.045455  0.272727             0.000000
# 4       0.000000      0.000000  0.217391             0.000000
# 5       0.033333      0.000000  0.500000             0.066667
# ..           ...           ...       ...                  ...
# 278     0.000000      0.000000  0.050000             0.000000
# 279     0.000000      0.030303  0.242424             0.000000
# 280     0.055556      0.111111  0.277778             0.000000
# 281     0.041096      0.109589  0.109589             0.013699
# 282     0.000000      0.083333  0.097222             0.000000
#
#      carries_into_final_third  carries_into_penalty_area
# 1                    0.000000                        0.0
# 2                    0.022222                        0.0
# 3                    0.000000                        0.0
# 4                    0.000000                        0.0
# 5                    0.022222                        0.0
# ..                        ...                        ...
# 278                  0.000000                        0.0
# 279                  0.030303                        0.0
# 280                  0.000000                        0.0
# 281                  0.000000                        0.0
# 282                  0.000000                        0.0
#
# [262 rows x 122 columns]

# %% [markdown]
# Save outfield players database to file.

# %%
db.to_excel('mid_outputs/database_entries.xlsx')

# %% [markdown]
# Do the same process for goalkeepers, generating a different database.

# %%
for i in range(db.columns.shape[0]):
    print(str(i) + " - " + str(db.columns[i]))
# Out:
# 0 - matchday
# 1 - player
# 2 - team
# 3 - oppteam
# 4 - home
# 5 - vote
# 6 - goals
# 7 - assists
# 8 - cards_malus
# 9 - fantavote
# 10 - r
# 11 - games
# 12 - games_starts
# 13 - minutes
# 14 - shots_on_target_pct
# 15 - goals_per_shot
# 16 - goals_per_shot_on_target
# 17 - passes_pct
# 18 - aerials_won_pct
# 19 - team_possession
# 20 - team_goals_assists_per90
# 21 - team_goals_pens_per90
# 22 - team_goals_assists_pens_per90
# 23 - team_xg_per90
# 24 - team_gk_goals_against_per90
# 25 - team_gk_save_pct
# 26 - team_gk_clean_sheets_pct
# 27 - team_passes_pct
# 28 - team_passes_pct_medium
# 29 - team_passes_pct_long
# 30 - team_sca_per90
# 31 - team_gca_per90
# 32 - team_aerials_won_pct
# 33 - vs_team_possession
# 34 - vs_team_goals_per90
# 35 - vs_team_assists_per90
# 36 - vs_team_xg_per90
# 37 - vs_team_gk_save_pct
# 38 - vs_team_gk_clean_sheets_pct
# 39 - vs_team_gk_pct_passes_launched
# 40 - vs_team_gk_crosses_stopped_pct
# 41 - vs_team_shots_on_target_per90
# 42 - vs_team_passes_pct
# 43 - vs_team_passes_pct_short
# 44 - vs_team_passes_pct_medium
# 45 - vs_team_passes_pct_long
# 46 - vs_team_sca_per90
# 47 - vs_team_gca_per90
# 48 - vs_team_aerials_won_pct
# 49 - opp_team_possession
# 50 - opp_team_goals_assists_per90
# 51 - opp_team_goals_pens_per90
# 52 - opp_team_goals_assists_pens_per90
# 53 - opp_team_xg_per90
# 54 - opp_team_gk_goals_against_per90
# 55 - opp_team_gk_save_pct
# 56 - opp_team_gk_clean_sheets_pct
# 57 - opp_team_passes_pct
# 58 - opp_team_passes_pct_medium
# 59 - opp_team_passes_pct_long
# 60 - opp_team_sca_per90
# 61 - opp_team_gca_per90
# 62 - opp_team_aerials_won_pct
# 63 - opp_vs_team_possession
# 64 - opp_vs_team_goals_per90
# 65 - opp_vs_team_assists_per90
# 66 - opp_vs_team_xg_per90
# 67 - opp_vs_team_gk_save_pct
# 68 - opp_vs_team_gk_clean_sheets_pct
# 69 - opp_vs_team_gk_pct_passes_launched
# 70 - opp_vs_team_gk_crosses_stopped_pct
# 71 - opp_vs_team_shots_on_target_per90
# 72 - opp_vs_team_passes_pct
# 73 - opp_vs_team_passes_pct_short
# 74 - opp_vs_team_passes_pct_medium
# 75 - opp_vs_team_passes_pct_long
# 76 - opp_vs_team_sca_per90
# 77 - opp_vs_team_gca_per90
# 78 - opp_vs_team_aerials_won_pct
# 79 - vote_avg
# 80 - vote_std
# 81 - goals
# 82 - assists
# 83 - cards_yellow
# 84 - cards_red
# 85 - xg
# 86 - npxg
# 87 - shots_on_target
# 88 - passes_completed
# 89 - passes_into_final_third
# 90 - passes_into_penalty_area
# 91 - progressive_passes
# 92 - passes_live
# 93 - passes_dead
# 94 - through_balls
# 95 - passes_switches
# 96 - crosses
# 97 - corner_kicks
# 98 - blocks
# 99 - blocked_shots
# 100 - blocked_passes
# 101 - interceptions
# 102 - clearances
# 103 - errors
# 104 - touches
# 105 - touches_def_pen_area
# 106 - touches_def_3rd
# 107 - touches_mid_3rd
# 108 - touches_att_3rd
# 109 - touches_att_pen_area
# 110 - touches_live_ball
# 111 - passes_received
# 112 - miscontrols
# 113 - dispossessed
# 114 - fouls
# 115 - fouled
# 116 - aerials_won
# 117 - aerials_lost
# 118 - carries
# 119 - progressive_carries
# 120 - carries_into_final_third
# 121 - carries_into_penalty_area

# %%
rx = pd.read_excel('tmp/playermatchdata_sel_gk.xlsx', index_col = 0, header = None)   

out = list()

for i in range(1, rx.shape[1]):
        if(rx[i][2] == "x"):
            out.append(rx[i][0])
            
out
# Out:
# ['r',
#  'fb_ID',
#  'gk_games',
#  'gk_games_starts',
#  'gk_minutes',
#  'gk_goals_against_per90',
#  'gk_shots_on_target_against',
#  'gk_saves',
#  'gk_save_pct',
#  'gk_clean_sheets_pct',
#  'gk_free_kick_goals_against',
#  'gk_corner_kick_goals_against',
#  'gk_own_goals_against',
#  'gk_psxg',
#  'gk_psnpxg_per_shot_on_target_against',
#  'gk_psxg_net',
#  'gk_psxg_net_per90',
#  'gk_passes_completed_launched',
#  'gk_passes_launched',
#  'gk_passes_pct_launched',
#  'gk_passes',
#  'gk_passes_throws',
#  'gk_pct_passes_launched',
#  'gk_passes_length_avg',
#  'gk_goal_kicks',
#  'gk_pct_goal_kicks_launched',
#  'gk_goal_kick_length_avg',
#  'gk_crosses',
#  'gk_crosses_stopped',
#  'gk_crosses_stopped_pct',
#  'gk_def_actions_outside_pen_area',
#  'gk_def_actions_outside_pen_area_per90',
#  'gk_avg_distance_def_actions',
#  'team_possession',
#  'team_goals_assists_per90',
#  'team_goals_pens_per90',
#  'team_goals_assists_pens_per90',
#  'team_xg_per90',
#  'team_gk_goals_against_per90',
#  'team_gk_save_pct',
#  'team_gk_clean_sheets_pct',
#  'team_passes_pct',
#  'team_passes_pct_medium',
#  'team_passes_pct_long',
#  'team_sca_per90',
#  'team_gca_per90',
#  'team_dribble_tackles_pct',
#  'team_aerials_won_pct',
#  'vs_team_possession',
#  'vs_team_goals_per90',
#  'vs_team_assists_per90',
#  'vs_team_xg_per90',
#  'vs_team_gk_save_pct',
#  'vs_team_gk_clean_sheets_pct',
#  'vs_team_gk_pct_passes_launched',
#  'vs_team_gk_crosses_stopped_pct',
#  'vs_team_shots_on_target_per90',
#  'vs_team_passes_pct',
#  'vs_team_passes_pct_short',
#  'vs_team_passes_pct_medium',
#  'vs_team_passes_pct_long',
#  'vs_team_sca_per90',
#  'vs_team_gca_per90',
#  'vs_team_dribble_tackles_pct',
#  'vs_team_dribbles_completed_pct',
#  'vs_team_aerials_won_pct']

# %%
features_abs_gk = [
 'gk_games',
 'gk_games_starts',
 'gk_minutes',
 'gk_goals_against_per90', 
 'gk_save_pct',
 'gk_clean_sheets_pct',
 'gk_psxg_net_per90',
 'gk_passes_pct_launched',
 'gk_pct_passes_launched',
 'gk_passes_length_avg',
 'gk_pct_goal_kicks_launched',
 'gk_goal_kick_length_avg',
 'gk_crosses_stopped_pct',
 'gk_def_actions_outside_pen_area_per90',
 'gk_avg_distance_def_actions',
    
 'team_possession',
 'team_goals_assists_per90',
 'team_goals_pens_per90',
 'team_goals_assists_pens_per90',
 'team_xg_per90',
 'team_gk_goals_against_per90',
 'team_gk_save_pct',
 'team_gk_clean_sheets_pct',
 'team_passes_pct',
 'team_passes_pct_medium',
 'team_passes_pct_long',
 'team_sca_per90',
 'team_gca_per90',
 #'team_dribble_tackles_pct',
 'team_aerials_won_pct',
 'vs_team_possession',
 'vs_team_goals_per90',
 'vs_team_assists_per90',
 'vs_team_xg_per90',
 'vs_team_gk_save_pct',
 'vs_team_gk_clean_sheets_pct',
 'vs_team_gk_pct_passes_launched',
 'vs_team_gk_crosses_stopped_pct',
 'vs_team_shots_on_target_per90',
 'vs_team_passes_pct',
 'vs_team_passes_pct_short',
 'vs_team_passes_pct_medium',
 'vs_team_passes_pct_long',
 'vs_team_sca_per90',
 'vs_team_gca_per90',
 #'vs_team_dribble_tackles_pct',
 #'vs_team_dribbles_completed_pct',
 'vs_team_aerials_won_pct',
 'opp_team_possession',
 'opp_team_goals_assists_per90',
 'opp_team_goals_pens_per90',
 'opp_team_goals_assists_pens_per90',
 'opp_team_xg_per90',
 'opp_team_gk_goals_against_per90',
 'opp_team_gk_save_pct',
 'opp_team_gk_clean_sheets_pct',
 'opp_team_passes_pct',
 'opp_team_passes_pct_medium',
 'opp_team_passes_pct_long',
 'opp_team_sca_per90',
 'opp_team_gca_per90',
 #'opp_team_dribble_tackles_pct',
 'opp_team_aerials_won_pct',
 'opp_vs_team_possession',
 'opp_vs_team_goals_per90',
 'opp_vs_team_assists_per90',
 'opp_vs_team_xg_per90',
 'opp_vs_team_gk_save_pct',
 'opp_vs_team_gk_clean_sheets_pct',
 'opp_vs_team_gk_pct_passes_launched',
 'opp_vs_team_gk_crosses_stopped_pct',
 'opp_vs_team_shots_on_target_per90',
 'opp_vs_team_passes_pct',
 'opp_vs_team_passes_pct_short',
 'opp_vs_team_passes_pct_medium',
 'opp_vs_team_passes_pct_long',
 'opp_vs_team_sca_per90',
 'opp_vs_team_gca_per90',
 #'opp_vs_team_dribble_tackles_pct',
 #'opp_vs_team_dribbles_completed_pct',
 'opp_vs_team_aerials_won_pct',
                
 'vote_avg',
 'vote_std']

features_rel_gk = [
 'gk_shots_on_target_against',
 'gk_saves',
 'gk_free_kick_goals_against',
 'gk_corner_kick_goals_against',
 'gk_own_goals_against',
 'gk_psxg',
 'gk_psnpxg_per_shot_on_target_against',
 'gk_psxg_net',
 'gk_passes_completed_launched',
 'gk_passes_launched',
 'gk_passes',
 'gk_passes_throws',
 'gk_goal_kicks',
 'gk_crosses',
 'gk_crosses_stopped',
]

# %%
def player_match_data_ext_gk(player, pteam, oppteam):
    pdata = player_match_data(player, pteam, oppteam)
    
    if(not isinstance(pdata, pd.DataFrame)):
        return None
    
    if(pdata['gk_games'][0] <= 0):
        return None
    
    out = pd.concat([pdata[features_abs_gk], pdata[features_rel_gk]], axis = 1)
    
    out[features_rel_gk] = out[features_rel_gk] / max(pdata['minutes'][0], 1)

    return out

# %%
test = player_match_data_ext_gk('Consigli', 'Sassuolo', 'Atalanta')

add_columns_gk = test.columns

test
# Out:
#           gk_games  gk_games_starts  gk_minutes  gk_goals_against_per90  \
# Consigli       4.0              4.0         360                     1.5
#
#           gk_save_pct  gk_clean_sheets_pct  gk_psxg_net_per90  \
# Consigli         66.7                  0.0              -0.47
#
#           gk_passes_pct_launched  gk_pct_passes_launched  \
# Consigli                    26.1                    45.7
#
#           gk_passes_length_avg  ...  gk_psxg  \
# Consigli                  39.4  ...      4.1
#
#           gk_psnpxg_per_shot_on_target_against  gk_psxg_net  \
# Consigli                                  0.21         -1.9
#
#           gk_passes_completed_launched  gk_passes_launched  gk_passes  \
# Consigli                          18.0                69.0      127.0
#
#           gk_passes_throws  gk_goal_kicks  gk_crosses  gk_crosses_stopped
# Consigli              14.0           42.0        73.0                 4.0
#
# [1 rows x 92 columns]

# %%
db_gk = votes.copy()

delta = pd.DataFrame(columns = add_columns_gk)

for i in range(db_gk.shape[0]):
    ext_data = player_match_data_ext_gk(db_gk['player'][i], db_gk['team'][i], db_gk['oppteam'][i])
    
    if(i % 100 == 0):
        print(i)
        
    if(not isinstance(ext_data, pd.DataFrame)):
        continue
    
    ext_data = ext_data.rename(index = {db_gk['player'][i] : i})
    
    delta = pd.concat([delta, ext_data], axis = 0)
    
    
    
db_gk = pd.concat([db_gk, delta], axis = 1)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700

# %%
db_gk
# Out:
#       matchday      player      team   oppteam  home  vote  goals  assists  \
# 0            1       Musso  Atalanta  Sassuolo     0   6.5      0        0
# 1            1  Zappacosta  Atalanta  Sassuolo     0   6.5      0        0
# 2            1    Djimsiti  Atalanta  Sassuolo     0   6.0      0        0
# 3            1   Kolasinac  Atalanta  Sassuolo     0   6.5      0        0
# 4            1      Zortea  Atalanta  Sassuolo     0   7.0      1        0
# ...        ...         ...       ...       ...   ...   ...    ...      ...
# 1726         6  Folorunsho    Verona  Atalanta     1   6.0      0        0
# 1727         6      Suslov    Verona  Atalanta     1   6.0      0        0
# 1728         6   Bonazzoli    Verona  Atalanta     1   5.5      0        0
# 1729         6       Henry    Verona  Atalanta     1   6.0      0        0
# 1730         6      Ngonge    Verona  Atalanta     1   5.0      0        0
#
#       cards_malus  fantavote  ...  gk_psxg  \
# 0             0.0        6.5  ...      2.1
# 1             0.0        6.5  ...      NaN
# 2             0.0        6.0  ...      NaN
# 3             0.0        6.5  ...      NaN
# 4             0.0       10.0  ...      NaN
# ...           ...        ...  ...      ...
# 1726          0.5        5.5  ...      NaN
# 1727          0.0        6.0  ...      NaN
# 1728          0.0        5.5  ...      NaN
# 1729          0.0        6.0  ...      NaN
# 1730          0.5        4.5  ...      NaN
#
#       gk_psnpxg_per_shot_on_target_against gk_psxg_net  \
# 0                                     0.21         0.1
# 1                                      NaN         NaN
# 2                                      NaN         NaN
# 3                                      NaN         NaN
# 4                                      NaN         NaN
# ...                                    ...         ...
# 1726                                   NaN         NaN
# 1727                                   NaN         NaN
# 1728                                   NaN         NaN
# 1729                                   NaN         NaN
# 1730                                   NaN         NaN
#
#       gk_passes_completed_launched  gk_passes_launched  gk_passes  \
# 0                             14.0                48.0      119.0
# 1                              NaN                 NaN        NaN
# 2                              NaN                 NaN        NaN
# 3                              NaN                 NaN        NaN
# 4                              NaN                 NaN        NaN
# ...                            ...                 ...        ...
# 1726                           NaN                 NaN        NaN
# 1727                           NaN                 NaN        NaN
# 1728                           NaN                 NaN        NaN
# 1729                           NaN                 NaN        NaN
# 1730                           NaN                 NaN        NaN
#
#       gk_passes_throws  gk_goal_kicks  gk_crosses  gk_crosses_stopped
# 0                 25.0           28.0        43.0                 4.0
# 1                  NaN            NaN         NaN                 NaN
# 2                  NaN            NaN         NaN                 NaN
# 3                  NaN            NaN         NaN                 NaN
# 4                  NaN            NaN         NaN                 NaN
# ...                ...            ...         ...                 ...
# 1726               NaN            NaN         NaN                 NaN
# 1727               NaN            NaN         NaN                 NaN
# 1728               NaN            NaN         NaN                 NaN
# 1729               NaN            NaN         NaN                 NaN
# 1730               NaN            NaN         NaN                 NaN
#
# [1731 rows x 102 columns]

# %%
db_gk = db_gk.drop(db_gk[db_gk.gk_games != db_gk.gk_games].index) # remove non extisting players

# %%
db_gk
# Out:
#       matchday               player         team   oppteam  home  vote  goals  \
# 0            1                Musso     Atalanta  Sassuolo     0   6.5      0
# 16           1            Skorupski      Bologna     Milan     1   6.0     -2
# 29           1            Radunovic     Cagliari    Torino     0   6.5      0
# 44           1              Caprile       Empoli    Verona     1   5.0     -1
# 57           1          Terracciano   Fiorentina     Genoa     0   6.0     -1
# ...        ...                  ...          ...       ...   ...   ...    ...
# 1657         6                Ochoa  Salernitana    Empoli     0   6.5     -1
# 1672         6             Consigli     Sassuolo     Inter     0   6.5     -1
# 1686         6  Milinkovic-Savic V.       Torino     Lazio     0   6.0     -2
# 1700         6            Silvestri      Udinese    Napoli     0   5.5     -4
# 1716         6             Montipo'       Verona  Atalanta     1   6.0     -1
#
#       assists  cards_malus  fantavote  ...    gk_psxg  \
# 0           0          0.0        6.5  ...   2.100000
# 16          0          0.0        4.0  ...   4.200000
# 29          0          0.0        6.5  ...   8.700000
# 44          0          0.0        4.0  ...   4.933333
# 57          0          0.0        5.0  ...   4.100000
# ...       ...          ...        ...  ...        ...
# 1657        0          0.0        5.5  ...   6.800000
# 1672        0          0.0        5.5  ...   4.100000
# 1686        0          0.0        4.0  ...   5.800000
# 1700        0          0.0        1.5  ...  10.100000
# 1716        0          0.0        5.0  ...   6.700000
#
#       gk_psnpxg_per_shot_on_target_against gk_psxg_net  \
# 0                                 0.210000         0.1
# 16                                0.250000         0.2
# 29                                0.360000        -0.3
# 44                                0.203333        -1.4
# 57                                0.240000         0.1
# ...                                    ...         ...
# 1657                              0.220000        -3.2
# 1672                              0.210000        -1.9
# 1686                              0.180000        -1.2
# 1700                              0.370000         0.1
# 1716                              0.210000         0.7
#
#       gk_passes_completed_launched  gk_passes_launched  gk_passes  \
# 0                        14.000000           48.000000      119.0
# 16                       28.000000           60.000000      159.0
# 29                       33.000000           80.000000      124.0
# 44                        8.666667           38.666667       83.0
# 57                       28.000000           57.000000      151.0
# ...                            ...                 ...        ...
# 1657                     20.000000           85.000000      160.0
# 1672                     18.000000           69.000000      127.0
# 1686                     42.000000          117.000000      193.0
# 1700                     19.000000           50.000000      132.0
# 1716                     55.000000          156.000000      183.0
#
#       gk_passes_throws  gk_goal_kicks  gk_crosses  gk_crosses_stopped
# 0            25.000000      28.000000   43.000000                 4.0
# 16           25.000000      34.000000   89.000000                 3.0
# 29           23.000000      57.000000   87.000000                 5.0
# 44           17.666667      17.333333   36.666667                 2.0
# 57           14.000000      22.000000   44.000000                 3.0
# ...                ...            ...         ...                 ...
# 1657         22.000000      47.000000   88.000000                 4.0
# 1672         14.000000      42.000000   73.000000                 4.0
# 1686         37.000000      50.000000   47.000000                 4.0
# 1700         23.000000      45.000000   69.000000                 1.0
# 1716         16.000000      50.000000   72.000000                 1.0
#
# [120 rows x 102 columns]

# %% [markdown]
# Save goalkeepers players database to file.

# %%
db_gk.to_excel('mid_outputs/database_entries_gk.xlsx')

# %%
for i in range(db_gk.columns.shape[0]):
    print(str(i) + " - " + str(db_gk.columns[i]))
# Out:
# 0 - matchday
# 1 - player
# 2 - team
# 3 - oppteam
# 4 - home
# 5 - vote
# 6 - goals
# 7 - assists
# 8 - cards_malus
# 9 - fantavote
# 10 - gk_games
# 11 - gk_games_starts
# 12 - gk_minutes
# 13 - gk_goals_against_per90
# 14 - gk_save_pct
# 15 - gk_clean_sheets_pct
# 16 - gk_psxg_net_per90
# 17 - gk_passes_pct_launched
# 18 - gk_pct_passes_launched
# 19 - gk_passes_length_avg
# 20 - gk_pct_goal_kicks_launched
# 21 - gk_goal_kick_length_avg
# 22 - gk_crosses_stopped_pct
# 23 - gk_def_actions_outside_pen_area_per90
# 24 - gk_avg_distance_def_actions
# 25 - team_possession
# 26 - team_goals_assists_per90
# 27 - team_goals_pens_per90
# 28 - team_goals_assists_pens_per90
# 29 - team_xg_per90
# 30 - team_gk_goals_against_per90
# 31 - team_gk_save_pct
# 32 - team_gk_clean_sheets_pct
# 33 - team_passes_pct
# 34 - team_passes_pct_medium
# 35 - team_passes_pct_long
# 36 - team_sca_per90
# 37 - team_gca_per90
# 38 - team_aerials_won_pct
# 39 - vs_team_possession
# 40 - vs_team_goals_per90
# 41 - vs_team_assists_per90
# 42 - vs_team_xg_per90
# 43 - vs_team_gk_save_pct
# 44 - vs_team_gk_clean_sheets_pct
# 45 - vs_team_gk_pct_passes_launched
# 46 - vs_team_gk_crosses_stopped_pct
# 47 - vs_team_shots_on_target_per90
# 48 - vs_team_passes_pct
# 49 - vs_team_passes_pct_short
# 50 - vs_team_passes_pct_medium
# 51 - vs_team_passes_pct_long
# 52 - vs_team_sca_per90
# 53 - vs_team_gca_per90
# 54 - vs_team_aerials_won_pct
# 55 - opp_team_possession
# 56 - opp_team_goals_assists_per90
# 57 - opp_team_goals_pens_per90
# 58 - opp_team_goals_assists_pens_per90
# 59 - opp_team_xg_per90
# 60 - opp_team_gk_goals_against_per90
# 61 - opp_team_gk_save_pct
# 62 - opp_team_gk_clean_sheets_pct
# 63 - opp_team_passes_pct
# 64 - opp_team_passes_pct_medium
# 65 - opp_team_passes_pct_long
# 66 - opp_team_sca_per90
# 67 - opp_team_gca_per90
# 68 - opp_team_aerials_won_pct
# 69 - opp_vs_team_possession
# 70 - opp_vs_team_goals_per90
# 71 - opp_vs_team_assists_per90
# 72 - opp_vs_team_xg_per90
# 73 - opp_vs_team_gk_save_pct
# 74 - opp_vs_team_gk_clean_sheets_pct
# 75 - opp_vs_team_gk_pct_passes_launched
# 76 - opp_vs_team_gk_crosses_stopped_pct
# 77 - opp_vs_team_shots_on_target_per90
# 78 - opp_vs_team_passes_pct
# 79 - opp_vs_team_passes_pct_short
# 80 - opp_vs_team_passes_pct_medium
# 81 - opp_vs_team_passes_pct_long
# 82 - opp_vs_team_sca_per90
# 83 - opp_vs_team_gca_per90
# 84 - opp_vs_team_aerials_won_pct
# 85 - vote_avg
# 86 - vote_std
# 87 - gk_shots_on_target_against
# 88 - gk_saves
# 89 - gk_free_kick_goals_against
# 90 - gk_corner_kick_goals_against
# 91 - gk_own_goals_against
# 92 - gk_psxg
# 93 - gk_psnpxg_per_shot_on_target_against
# 94 - gk_psxg_net
# 95 - gk_passes_completed_launched
# 96 - gk_passes_launched
# 97 - gk_passes
# 98 - gk_passes_throws
# 99 - gk_goal_kicks
# 100 - gk_crosses
# 101 - gk_crosses_stopped
